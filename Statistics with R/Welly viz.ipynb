# %%
library(ggplot2)

# %%
df = read.csv(file = './welly.csv', header = TRUE, sep = ',')

# %%
df$Time = as.factor(df$Time)

# %%
ggplot(data = df) + 
    geom_bar(mapping = aes(x = Difficulty, y = Depth, fill = Time), stat = 'identity', position ='dodge')
# Out:
# plot without title
