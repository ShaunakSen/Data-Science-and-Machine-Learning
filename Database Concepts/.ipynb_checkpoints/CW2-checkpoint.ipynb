# %% [markdown]
# # Coursework 2: Data Processing
#
# ## Task 1
# This coursework will assess your understanding of using NoSQL to store and retrieve data.  You will perform operations on data from the Enron email dataset in a MongoDB database, and write a report detailing the suitability of different types of databases for data science applications.  You will be required to run code to answer the given questions in the Jupyter notebook provided, and write a report describing alternative approaches to using MongoDB.
#
# Download the JSON version of the Enron data (using the “Download as zip” to download the data file from http://edshare.soton.ac.uk/19548/, the file is about 380MB) and import into a collection called messages in a database called enron.  You do not need to set up any authentication.  In the Jupyter notebook provided, perform the following tasks, using the Python PyMongo library.
#
# Answers should be efficient in terms of speed.  Answers which are less efficient will not get full marks.

# %% [markdown]
# ### Importing the dataset
#
# The JSON version of the dataset has been downloaded from [this link](http://edshare.soton.ac.uk/19548/)
#
# The dataset has been imported into the database **enron**
#
# The name of the collection is **messages**
#
# **100000** documents have been imported

# %%
# %%bash
#
# # mongoimport is the Mongo command to import data.
# # It specifies the database, collection and format, and import file
# # --drop means it's going to drop any collection with the same name which already exists
# mongoimport --db enron_short --collection messages --drop --file ./messages_short.json
# # Delete the JSON file we just downloaded
# rm ./messages_short.json
# Out:
# 2018-12-08T19:40:19.811+0000	connected to: localhost
# 2018-12-08T19:40:19.811+0000	dropping: enron_short.messages
# 2018-12-08T19:40:22.810+0000	[######..................] enron_short.messages	94.5MB/354MB (26.7%)
# 2018-12-08T19:40:25.811+0000	[#############...........] enron_short.messages	201MB/354MB (56.8%)
# 2018-12-08T19:40:28.810+0000	[###################.....] enron_short.messages	290MB/354MB (82.0%)
# 2018-12-08T19:40:31.810+0000	[######################..] enron_short.messages	329MB/354MB (92.9%)
# 2018-12-08T19:40:34.478+0000	[########################] enron_short.messages	354MB/354MB (100.0%)
# 2018-12-08T19:40:34.478+0000	imported 100000 documents

# %%
import pymongo
from pymongo import MongoClient
from datetime import datetime
from pprint import pprint

import re

from datetime import datetime

# %%
client = MongoClient('mongodb://localhost:27017')

client.list_database_names()
# Out:
# ['admin', 'config', 'enron_short', 'local']

# %% [markdown]
# ### 1)
# Write a function which returns a MongoDB connection object to the "messages" collection. [4 points]

# %%
db_name = 'enron_short'
coll_name = 'messages'

def get_collection():
    """
    Connects to the server, and returns a collection object
    of the `messages` collection in the `enron` database
    """
    # YOUR CODE HERE
    
    client = MongoClient('mongodb://localhost:27017')
    
    if db_name in client.list_database_names():
        db = client.enron_short
        # check if collection is present
        if coll_name in db.list_collection_names():
            collection = db[coll_name]
        else:
            return "Collection:", coll_name, "not found"
    else:
        return "Database:", db_name, "not found"
    
    return collection
            
        
messages_collection = get_collection()

# %% [markdown]
# Verifying that collection connection is able to read all documents

# %%
messages_collection.count_documents({})
# Out:
# 100000

# %% [markdown]
# ### 2)
#
# Write a function which returns the amount of emails in the messages collection in total. [4 points]

# %%
def get_amount_of_messages(collection):
    """
    :param collection A PyMongo collection object
    :return the amount of documents in the collection
    """    
    # YOUR CODE HERE
    return messages_collection.count_documents({})
number_of_emails = get_amount_of_messages(messages_collection)    

print (number_of_emails)
# Out:
# 100000

# %% [markdown]
# ### 3)
#
# Write a function which returns each person who was BCCed on an email.  Include each person only once, and display only their name according to the X-To header. [4 points]

# %%
bcc_list = []

bcc_list1 = []
bcc_list2 = []
bcc_list3 = []

final_list = []

# find docs where bcc field exists and is not empty

for doc in messages_collection.find({ 'headers.X-bcc': {'$exists': True, '$ne': ''} }):
    bcc_list.append(doc['headers']['X-bcc'])
    
for bcc_value in bcc_list:
    bcc_list1.append(bcc_value.split('>,'))
    
bcc_list1[0]

for bcc_value in bcc_list1:
    for value in bcc_value:
        bcc_list2.append(value.split('</O')[0])
        
for bcc_value in bcc_list2:
    bcc_list3.append(bcc_value.split(' <')[0])
        
bcc_list3

for bcc_value in bcc_list3:
    if '@' not in bcc_value:
        if bcc_value.strip() not in final_list:
            final_list.append(bcc_value.strip())

final_list
# Out:
# ['Villarreal, Alex',
#  'Vuittonet, Laura',
#  'Wood, Kim',
#  'Choate, Heather',
#  'Rangel, Ina',
#  'Hogan, Irena D.',
#  'Westbrook, Cherylene R.',
#  'De La Paz, Janet',
#  'Beck, Sally',
#  'Denny, Jennifer',
#  'Piper, Greg',
#  'Patti Thompson',
#  'Robert Superty',
#  'Beth Apollo',
#  'Greg Piper',
#  'Apollo, Beth',
#  'Barry, Patrick',
#  'Blair, Jean',
#  'Bryan, Randy',
#  'Callans, Nancy',
#  'Carr, James',
#  'Clapper, Karen',
#  'Perry, Renee',
#  'Porter, Diana',
#  'Walden, Shirley',
#  'Washington, Kathy',
#  'Causey, Richard',
#  'Dyson, Fernley',
#  'Jordan, Mike',
#  'Lokey, Teb',
#  'Ratliff, Dale',
#  'Shapiro, Richard',
#  'Dernehl, Ginger',
#  'Guerrero, Janel',
#  'Steffes, James D.',
#  'Richard Shapiro',
#  'James D Steffes',
#  'Susan J Mara',
#  'Harry Kingerski',
#  'hgovenar',
#  'Scott Govenar',
#  'Davis, Dana',
#  'Ogenyi, Gloria',
#  'Collins, Harry',
#  'Cooley, Jan',
#  'Johnson, Jan',
#  'McBride, Jane',
#  'Wilson, Jane',
#  'Butler, Janet',
#  'Place, Janet',
#  'Moore, Janice',
#  'Desrochers, Jim',
#  'Lamb, John',
#  'Novak, John',
#  'Schwartzenburg, John',
#  'Viverito, John',
#  'Murray, Julia',
#  'Delahay, Julie',
#  'Boyd, Justin',
#  'Jones, Karen E.',
#  'Azevedo, Karla',
#  'Cole, Kate',
#  'Carnahan, Kathleen',
#  'Sullivan, Kathleen',
#  'Young, Kay',
#  'Leibman, Lara',
#  'Bishop, Larry',
#  'Pardue, Larry',
#  'Hagerty, Lauren',
#  'Mayer, Laurie',
#  'Kasbekar, Lena',
#  'Guinn, Linda',
#  'Mellencamp, Lisa',
#  'Robichaux, Lisa',
#  'Nettelton, Marcus',
#  'Trevino, Maricela',
#  'Haedicke, Mark',
#  'Evans, Mark',
#  'Greenberg, Mark',
#  'Holsworth, Mark',
#  'Powell, Mark',
#  'Taylor, Mark',
#  'Braddy, Martha',
#  'Cook, Mary',
#  'Oscar, Mary Denise',
#  'Heinitz, Mary',
#  'Ogden, Mary',
#  'Dawson, Matthew',
#  'Lee, Matthias',
#  'Robison, Michael',
#  'Smalling, Michael J.',
#  'Cash, Michelle',
#  'Robertson, Audrey',
#  'Wehring, Linda',
#  'Storey, Geoff',
#  'Gilbert-smith, Doug',
#  'Twiggs, Thane']

# %%
def get_bcced_people(collection):
    """
    :param collection A PyMongo collection object
    :return the names of the people who have received an email by BCC
    """    
    # YOUR CODE HERE

    pass

# %% [markdown]
# ### 4)
#
# Write a function with parameter subject, which gets all emails in a thread with that parameter, and orders them by date (ascending). “An email thread is an email message that includes a running list of all the succeeding replies starting with the original email.”, check for detail descriptions at https://www.techopedia.com/definition/1503/email-thread [4 points]

# %%
def get_emails_in_thread(collection, subject):
    """
    :param collection A PyMongo collection object
    :return All emails in the thread with that subject
    """    
    # YOUR CODE HERE    
    
    pass

# %%
for doc in messages_collection.find({}).limit(10):
    pprint(doc['headers'])
# Out:
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 08:22:00 -0800 (PST)',
#  'From': 'michael.simmons@enron.com',
#  'Message-ID': '<6884142.1075854677416.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'Re: Plays and other information',
#  'To': 'eric.bass@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': 'Michael Simmons',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Eric Bass',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 07:37:00 -0800 (PST)',
#  'From': 'michael.simmons@enron.com',
#  'Message-ID': '<6098626.1075854677438.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'Re: Plays and other information',
#  'To': 'eric.bass@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': 'Michael Simmons',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Eric Bass',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Bcc': 'jason.bass2@compaq.com',
#  'Cc': 'jason.bass2@compaq.com',
#  'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 07:25:00 -0800 (PST)',
#  'From': 'daphneco64@bigplanet.com',
#  'Message-ID': '<24383193.1075854677459.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'Re: check it out',
#  'To': 'eric.bass@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': '"K. Bass" <daphneco64@bigplanet.com>',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Eric.Bass@enron.com',
#  'X-bcc': '',
#  'X-cc': '"Bass, Jason" <Jason.Bass2@COMPAQ.com>'}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 08:32:00 -0800 (PST)',
#  'From': 'bryant@cheatsheets.net',
#  'Message-ID': '<8062419.1075854677483.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': '[cheatsheets] Brian Griese Injury',
#  'To': 'cheatsheets@egroups.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': '"Joe Bryant" <bryant@cheatsheets.net>',
#  'X-Origin': 'Bass-E',
#  'X-To': '"Cheatsheets Mailing List" <cheatsheets@egroups.com>',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=ANSI_X3.4-1968',
#  'Date': 'Tue, 14 Nov 2000 05:39:00 -0800 (PST)',
#  'From': 'daphneco64@bigplanet.com',
#  'Message-ID': '<32712651.1075854677554.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'instruct.jpg',
#  'To': 'lwbthemarine@bigplanet.com, jason.bass2@compaq.com, '
#        'eric.bass@enron.com, \r\n'
#        '\tchebert108@aol.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': '"K. Bass" <daphneco64@bigplanet.com>',
#  'X-Origin': 'Bass-E',
#  'X-To': '"Larry W. Bass" <lwbthemarine@bigplanet.com>, "Bass, Jason" '
#          '<Jason.Bass2@COMPAQ.com>, Eric Bass <Eric.Bass@enron.com>, '
#          'CHebert108@aol.com',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 03:22:00 -0800 (PST)',
#  'From': 'steve.venturatos@enron.com',
#  'Message-ID': '<9317476.1075854677600.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'fwd: FW: Fwd: Picture worth a thousand words',
#  'To': 'jody.crook@enron.com, david.baumbach@enron.com, '
#        'kelly.lombardi@enron.com, \r\n'
#        '\tbryan.hull@enron.com, eric.bass@enron.com, '
#        'patrick.ryder@enron.com, \r\n'
#        '\tdenver.plachy@enron.com, yvette.connevey@enron.com, \r\n'
#        '\tpat.clynes@enron.com, daren.farmer@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': 'Steve Venturatos',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Jody Crook, David Baumbach, Kelly Lombardi, Bryan Hull, Eric Bass, '
#          'Patrick Ryder, Denver Plachy, Yvette G Connevey, Pat Clynes, Daren J '
#          'Farmer',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=ANSI_X3.4-1968',
#  'Date': 'Tue, 14 Nov 2000 03:11:00 -0800 (PST)',
#  'From': 'customers@travelnow.com',
#  'Message-ID': '<12310096.1075854677532.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': "Here's The Deal .......... Surprise Jamaican Vacation!",
#  'To': 'ebass@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': '"TravelNow.com" <customers@travelnow.com>',
#  'X-Origin': 'Bass-E',
#  'X-To': '"ebass@enron.com" <ebass@enron.com>',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 03:00:00 -0800 (PST)',
#  'From': 'luis.mena@enron.com',
#  'Message-ID': '<296353.1075854677622.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': '',
#  'To': 'eric.bass@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': 'Luis Mena',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Eric Bass',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 06:59:00 -0800 (PST)',
#  'From': 'matthew.lenhart@enron.com',
#  'Message-ID': '<12292910.1075854677508.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'Sorry, I keep getting these things.',
#  'To': 'chad.landry@enron.com, timothy.blanchard@enron.com, '
#        'bryan.hull@enron.com, \r\n'
#        '\teric.bass@enron.com, phillip.love@enron.com, \r\n'
#        '\tkenneth.shulklapper@enron.com, jay.reitmeyer@enron.com, \r\n'
#        '\ttori.kuykendall@enron.com, lisa.gillette@enron.com, \r\n'
#        '\tchrista.winfrey@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': 'Matthew Lenhart',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Chad Landry, Timothy Blanchard, Bryan Hull, Eric Bass, Phillip M '
#          'Love, Kenneth Shulklapper, Jay Reitmeyer, Tori Kuykendall, Lisa '
#          'Gillette, Christa Winfrey',
#  'X-bcc': '',
#  'X-cc': ''}
# {'Content-Transfer-Encoding': '7bit',
#  'Content-Type': 'text/plain; charset=us-ascii',
#  'Date': 'Tue, 14 Nov 2000 02:47:00 -0800 (PST)',
#  'From': 'shanna.husser@enron.com',
#  'Message-ID': '<20555316.1075854677668.JavaMail.evans@thyme>',
#  'Mime-Version': '1.0',
#  'Subject': 'Gore Priceless',
#  'To': 'eric.bass@enron.com',
#  'X-FileName': 'ebass.nsf',
#  'X-Folder': '\\Eric_Bass_Dec2000\\Notes Folders\\Notes inbox',
#  'X-From': 'Shanna Husser',
#  'X-Origin': 'Bass-E',
#  'X-To': 'Eric Bass',
#  'X-bcc': '',
#  'X-cc': ''}

# %%
datetime.strptime('Tue, 14 Nov 2000 08:22:00', '%a, %d %b %Y %H:%M:%S')
# Out:
# datetime.datetime(2000, 11, 14, 8, 22)

# %%
sub1 = "Plays and other information"

sub2 = "Re: " + sub1

limit_stage = {
    '$limit': 100
}

match_stage = {
    '$match': { 'headers.Subject': { '$in': [sub1, sub2] } }
}

project_stage = {
     '$project': { 'DateOfMessage': 
                      {'$dateFromString': { 'dateString' : 
                                           { '$rtrim': {'input': {'$substr': ['$headers.Date', 0, 25] }}}
                                          
                                          }
                      },
                        
                        'filename': 1,
                        'headers.Subject': 1,
                        'headers.Date': 1
                 } 
}

sort_stage = {
    '$sort': {'DateOfMessage': 1}
}


pipeline = [limit_stage, project_stage, sort_stage]

for doc in messages_collection.aggregate(pipeline):
    #pprint(doc['headers']['Date'][:-12])
    #pprint(datetime.strptime(doc['headers']['Date'][:-12], '%a, %d %b %Y %H:%M:%S'))
    
    pprint(doc)
# Out:
# {'DateOfMessage': datetime.datetime(2000, 11, 8, 9, 45),
#  '_id': ObjectId('4f16fc97d1e2d32371003e70'),
#  'filename': '516.',
#  'headers': {'Date': 'Wed, 8 Nov 2000 09:45:00 -0800 (PST)',
#              'Subject': 'Las Vegas from $39.95/nt! Plus Super Hot Hotel '
#                         'Bargains throughout\r\n'
#                         ' the U.S., Europe and the Caribbean!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 0, 19),
#  '_id': ObjectId('4f16fc97d1e2d32371003e88'),
#  'filename': '538.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 00:19:00 -0800 (PST)',
#              'Subject': 'If you have 5 minutes'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 0, 19),
#  '_id': ObjectId('4f16fc97d1e2d32371003e89'),
#  'filename': '539.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 00:19:00 -0800 (PST)',
#              'Subject': 'Outage for Unify Gas Users'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 0, 21),
#  '_id': ObjectId('4f16fc97d1e2d32371003e87'),
#  'filename': '537.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 00:21:00 -0800 (PST)',
#              'Subject': 'Re: Outage for Unify Gas Users'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 1, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e86'),
#  'filename': '536.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 01:22:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for Big E 11/10/00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 1, 45),
#  '_id': ObjectId('4f16fc97d1e2d32371003e83'),
#  'filename': '533.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 01:45:00 -0800 (PST)', 'Subject': ''}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 1, 50),
#  '_id': ObjectId('4f16fc97d1e2d32371003e85'),
#  'filename': '535.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 01:50:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM Transaction Request'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 2, 5),
#  '_id': ObjectId('4f16fc97d1e2d32371003e82'),
#  'filename': '532.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 02:05:00 -0800 (PST)',
#              'Subject': 'Palm Beach Voters'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 2, 39),
#  '_id': ObjectId('4f16fc97d1e2d32371003e84'),
#  'filename': '534.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 02:39:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for The Perfect League '
#                         '11/10/00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 2, 50),
#  '_id': ObjectId('4f16fc97d1e2d32371003e7c'),
#  'filename': '527.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 02:50:00 -0800 (PST)',
#              'Subject': 'SFX Music / Houston Concert Update!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 3, 18),
#  '_id': ObjectId('4f16fc97d1e2d32371003e81'),
#  'filename': '531.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 03:18:00 -0800 (PST)',
#              'Subject': 'CBS SPORTSLINE FOOTBALL COMMISSIONER NEWSLETTER'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 4, 2),
#  '_id': ObjectId('4f16fc97d1e2d32371003e7d'),
#  'filename': '528.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 04:02:00 -0800 (PST)', 'Subject': ''}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 6, 33),
#  '_id': ObjectId('4f16fc97d1e2d32371003e7b'),
#  'filename': '526.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 06:33:00 -0800 (PST)',
#              'Subject': 'Re: Friday'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 7, 19),
#  '_id': ObjectId('4f16fc97d1e2d32371003e7a'),
#  'filename': '525.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 07:19:00 -0800 (PST)',
#              'Subject': 'FW: bad santa'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 8, 44),
#  '_id': ObjectId('4f16fc97d1e2d32371003e80'),
#  'filename': '530.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 08:44:00 -0800 (PST)',
#              'Subject': 'Weekend PEP Support'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 9, 29),
#  '_id': ObjectId('4f16fc97d1e2d32371003e79'),
#  'filename': '524.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 09:29:00 -0800 (PST)',
#              'Subject': 'SUPPLEMENTAL Weekend Outage Report for 11-10-00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 9, 46),
#  '_id': ObjectId('4f16fc97d1e2d32371003e78'),
#  'filename': '523.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 09:46:00 -0800 (PST)',
#              'Subject': 'eThink About It: November 13, 2000'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 9, 47),
#  '_id': ObjectId('4f16fc97d1e2d32371003e76'),
#  'filename': '521.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 09:47:00 -0800 (PST)',
#              'Subject': 'Metro 214 and 216 downtown route changes'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 9, 56),
#  '_id': ObjectId('4f16fc97d1e2d32371003e7e'),
#  'filename': '529.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 09:56:00 -0800 (PST)',
#              'Subject': '[cheatsheets] Email Update #127 (Players in the '
#                         'News/Cheatsheet)'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 10, 25),
#  '_id': ObjectId('4f16fc97d1e2d32371003e77'),
#  'filename': '522.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 10:25:00 -0800 (PST)',
#              'Subject': 'Complete the Thanksgiving Feast!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 14, 38),
#  '_id': ObjectId('4f16fc97d1e2d32371003e75'),
#  'filename': '520.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 14:38:00 -0800 (PST)',
#              'Subject': 'Bush News: 11/10/00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 17, 31),
#  '_id': ObjectId('4f16fc97d1e2d32371003e73'),
#  'filename': '519.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 17:31:00 -0800 (PST)', 'Subject': 'Re:'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 10, 19, 31),
#  '_id': ObjectId('4f16fc97d1e2d32371003e72'),
#  'filename': '518.',
#  'headers': {'Date': 'Fri, 10 Nov 2000 19:31:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for Y2KG 11/11/00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 5, 34),
#  '_id': ObjectId('4f16fc97d1e2d32371003e6f'),
#  'filename': '515.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 05:34:00 -0800 (PST)',
#              'Subject': 'The County By County Mandate For Bush - See For '
#                         'Yourself'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 6, 15),
#  '_id': ObjectId('4f16fc97d1e2d32371003e71'),
#  'filename': '517.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 06:15:00 -0800 (PST)',
#              'Subject': '9 INCHES OF SNOW IN TELLURIDE!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 13, 31),
#  '_id': ObjectId('4f16fc97d1e2d32371003e6a'),
#  'filename': '510.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 13:31:00 -0800 (PST)',
#              'Subject': 'Re: Re:'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 13, 32),
#  '_id': ObjectId('4f16fc97d1e2d32371003e6c'),
#  'filename': '512.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 13:32:00 -0800 (PST)',
#              'Subject': 'Fw: Voter Competency Test'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 14, 7),
#  '_id': ObjectId('4f16fc97d1e2d32371003e6b'),
#  'filename': '511.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 14:07:00 -0800 (PST)',
#              'Subject': 'Fw: Where Did We Go Wrong'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 16, 29),
#  '_id': ObjectId('4f16fc97d1e2d32371003e6d'),
#  'filename': '513.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 16:29:00 -0800 (PST)',
#              'Subject': '[cheatsheets] #128 Updated Players in the News '
#                         '(11-11-00)'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 11, 16, 37),
#  '_id': ObjectId('4f16fc97d1e2d32371003e6e'),
#  'filename': '514.',
#  'headers': {'Date': 'Sat, 11 Nov 2000 16:37:00 -0800 (PST)',
#              'Subject': '[cheatsheets] #129 TFL Report News (11-11-00)'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 12, 10, 6),
#  '_id': ObjectId('4f16fc97d1e2d32371003e68'),
#  'filename': '509.',
#  'headers': {'Date': 'Sun, 12 Nov 2000 10:06:00 -0800 (PST)', 'Subject': 'hey'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 12, 10, 15),
#  '_id': ObjectId('4f16fc97d1e2d32371003e67'),
#  'filename': '508.',
#  'headers': {'Date': 'Sun, 12 Nov 2000 10:15:00 -0800 (PST)',
#              'Subject': '[cheatsheets] Bad News - Ricky Williams'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 12, 10, 52),
#  '_id': ObjectId('4f16fc97d1e2d32371003e66'),
#  'filename': '507.',
#  'headers': {'Date': 'Sun, 12 Nov 2000 10:52:00 -0800 (PST)',
#              'Subject': 'A Message from Don Evans'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 12, 13, 7),
#  '_id': ObjectId('4f16fc97d1e2d32371003e65'),
#  'filename': '506.',
#  'headers': {'Date': 'Sun, 12 Nov 2000 13:07:00 -0800 (PST)',
#              'Subject': 'Conflict of Interest Policy Mailing to Vendors'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 12, 19, 8),
#  '_id': ObjectId('4f16fc97d1e2d32371003e64'),
#  'filename': '505.',
#  'headers': {'Date': 'Sun, 12 Nov 2000 19:08:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for Y2KG 11/13/00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 12, 21, 19),
#  '_id': ObjectId('4f16fc97d1e2d32371003e41'),
#  'filename': '474.',
#  'headers': {'Date': 'Sun, 12 Nov 2000 21:19:00 -0800 (PST)',
#              'Subject': 'SFX Music / Houston Concert Update'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 0, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e62'),
#  'filename': '503.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 00:22:00 -0800 (PST)',
#              'Subject': 'Please pass on to your groups'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 0, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e63'),
#  'filename': '504.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 00:22:00 -0800 (PST)',
#              'Subject': 'brown bags'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 0, 34),
#  '_id': ObjectId('4f16fc97d1e2d32371003e61'),
#  'filename': '502.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 00:34:00 -0800 (PST)', 'Subject': ''}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 1, 17),
#  '_id': ObjectId('4f16fc97d1e2d32371003e60'),
#  'filename': '501.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 01:17:00 -0800 (PST)', 'Subject': ''}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 1, 41),
#  '_id': ObjectId('4f16fc97d1e2d32371003e5c'),
#  'filename': '499.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 01:41:00 -0800 (PST)',
#              'Subject': 'Editorial The Hijacking of the Presidency'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 2, 17),
#  '_id': ObjectId('4f16fc97d1e2d32371003e5b'),
#  'filename': '498.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 02:17:00 -0800 (PST)',
#              'Subject': 'WE HAVE THE TICKETS!!!!!!!!!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 2, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e5a'),
#  'filename': '497.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 02:22:00 -0800 (PST)',
#              'Subject': "Kids Find Contested Ballot to be Child's Play"}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 2, 26),
#  '_id': ObjectId('4f16fc97d1e2d32371003e59'),
#  'filename': '496.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 02:26:00 -0800 (PST)',
#              'Subject': 'RE: Telluride E-Ride Newsletter'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 2, 27),
#  '_id': ObjectId('4f16fc97d1e2d32371003e5f'),
#  'filename': '500.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 02:27:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for Big E 11/13/00'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 2, 40),
#  '_id': ObjectId('4f16fc97d1e2d32371003e58'),
#  'filename': '495.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 02:40:00 -0800 (PST)',
#              'Subject': 'Re: A&M/UT Flag Football Invitation'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 2, 41),
#  '_id': ObjectId('4f16fc97d1e2d32371003e57'),
#  'filename': '494.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 02:41:00 -0800 (PST)',
#              'Subject': 'Re: WE HAVE THE TICKETS!!!!!!!!!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 3, 0),
#  '_id': ObjectId('4f16fc97d1e2d32371003e56'),
#  'filename': '493.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 03:00:00 -0800 (PST)',
#              'Subject': 'Re: WE HAVE THE TICKETS!!!!!!!!!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 3, 8),
#  '_id': ObjectId('4f16fc97d1e2d32371003e55'),
#  'filename': '492.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 03:08:00 -0800 (PST)',
#              'Subject': 'Practice - TONIGHT'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 3, 24),
#  '_id': ObjectId('4f16fc97d1e2d32371003e54'),
#  'filename': '491.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 03:24:00 -0800 (PST)',
#              'Subject': "Fw: What to Do if Gore Won't Concede After a Bush "
#                         'Victory'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 3, 54),
#  '_id': ObjectId('4f16fc97d1e2d32371003e53'),
#  'filename': '490.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 03:54:00 -0800 (PST)',
#              'Subject': 'Re: Friday'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 5, 18),
#  '_id': ObjectId('4f16fc97d1e2d32371003e51'),
#  'filename': '489.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 05:18:00 -0800 (PST)',
#              'Subject': 'Fwd: Election concession & retraction parody. Has '
#                         'good audio also.'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 6, 17),
#  '_id': ObjectId('4f16fc97d1e2d32371003e50'),
#  'filename': '488.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 06:17:00 -0800 (PST)',
#              'Subject': 'Re: Practice - TONIGHT'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 6, 23),
#  '_id': ObjectId('4f16fc97d1e2d32371003e4f'),
#  'filename': '487.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 06:23:00 -0800 (PST)', 'Subject': ''}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 6, 41),
#  '_id': ObjectId('4f16fc97d1e2d32371003e4d'),
#  'filename': '485.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 06:41:00 -0800 (PST)',
#              'Subject': 'Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 6, 45),
#  '_id': ObjectId('4f16fc97d1e2d32371003e4e'),
#  'filename': '486.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 06:45:00 -0800 (PST)', 'Subject': 'Re:'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 6, 55),
#  '_id': ObjectId('4f16fc97d1e2d32371003e4c'),
#  'filename': '484.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 06:55:00 -0800 (PST)',
#              'Subject': 'Re: Friday'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 7, 9),
#  '_id': ObjectId('4f16fc97d1e2d32371003e4b'),
#  'filename': '483.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 07:09:00 -0800 (PST)',
#              'Subject': 'Fw: The Latest Official Florida Presential Ballot'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 7, 17),
#  '_id': ObjectId('4f16fc97d1e2d32371003e4a'),
#  'filename': '482.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 07:17:00 -0800 (PST)',
#              'Subject': '15% Thanksgiving Savings from FTD.COM'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 7, 57),
#  '_id': ObjectId('4f16fc97d1e2d32371003e49'),
#  'filename': '481.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 07:57:00 -0800 (PST)',
#              'Subject': 'Re: Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 8, 8),
#  '_id': ObjectId('4f16fc97d1e2d32371003e48'),
#  'filename': '480.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 08:08:00 -0800 (PST)',
#              'Subject': 'Re: Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 8, 16),
#  '_id': ObjectId('4f16fc97d1e2d32371003e44'),
#  'filename': '477.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 08:16:00 -0800 (PST)',
#              'Subject': 'Re: Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 8, 16),
#  '_id': ObjectId('4f16fc97d1e2d32371003e45'),
#  'filename': '478.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 08:16:00 -0800 (PST)',
#              'Subject': 'Re: Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 8, 17),
#  '_id': ObjectId('4f16fc97d1e2d32371003e46'),
#  'filename': '479.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 08:17:00 -0800 (PST)',
#              'Subject': 'Re: Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 8, 27),
#  '_id': ObjectId('4f16fc97d1e2d32371003e43'),
#  'filename': '476.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 08:27:00 -0800 (PST)',
#              'Subject': 'Re: Thanksgiving dinner'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 10, 42),
#  '_id': ObjectId('4f16fc97d1e2d32371003e3e'),
#  'filename': '471.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 10:42:00 -0800 (PST)',
#              'Subject': "Chairman's Award Nominations"}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 10, 46),
#  '_id': ObjectId('4f16fc97d1e2d32371003e42'),
#  'filename': '475.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 10:46:00 -0800 (PST)',
#              'Subject': 'Holiday Schedule 2001'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 12, 56),
#  '_id': ObjectId('4f16fc97d1e2d32371003e40'),
#  'filename': '473.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 12:56:00 -0800 (PST)',
#              'Subject': 'URGENT: Help Preserve the Bush Victory'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 14, 37),
#  '_id': ObjectId('4f16fc97d1e2d32371003e3d'),
#  'filename': '470.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 14:37:00 -0800 (PST)',
#              'Subject': 'Turkey/Santa Fares For USA, Europe, Canada, Australia '
#                         '& New Zealand'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 16, 53),
#  '_id': ObjectId('4f16fc97d1e2d32371003e3f'),
#  'filename': '472.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 16:53:00 -0800 (PST)',
#              'Subject': '[cheatsheets] #130 Upgrades - Downgrades (11-13-00)'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 22, 37),
#  '_id': ObjectId('4f16fc97d1e2d32371003e3b'),
#  'filename': '469.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 22:37:00 -0800 (PST)',
#              'Subject': "Click 'n Save Internet Specials November 14, 2000"}}
# {'DateOfMessage': datetime.datetime(2000, 11, 13, 23, 24),
#  '_id': ObjectId('4f16fc97d1e2d32371003e3a'),
#  'filename': '468.',
#  'headers': {'Date': 'Mon, 13 Nov 2000 23:24:00 -0800 (PST)',
#              'Subject': 'Fwd: A woman and a man are involved in a car '
#                         "accident; it's a"}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 0, 42),
#  '_id': ObjectId('4f16fc97d1e2d32371003e39'),
#  'filename': '467.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 00:42:00 -0800 (PST)',
#              'Subject': 'A/A Timesheets for Nov.1-15, 2000'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 1, 40),
#  '_id': ObjectId('4f16fc97d1e2d32371003e38'),
#  'filename': '466.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 01:40:00 -0800 (PST)', 'Subject': 'RE:'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 2, 5),
#  '_id': ObjectId('4f16fc97d1e2d32371003e37'),
#  'filename': '465.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 02:05:00 -0800 (PST)',
#              'Subject': 'protest'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 2, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e36'),
#  'filename': '464.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 02:22:00 -0800 (PST)',
#              'Subject': 'Aggie vs t.u. Flag Football'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 2, 27),
#  '_id': ObjectId('4f16fc97d1e2d32371003e35'),
#  'filename': '463.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 02:27:00 -0800 (PST)',
#              'Subject': 'November 14 cancelled'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 2, 40),
#  '_id': ObjectId('4f16fc97d1e2d32371003e34'),
#  'filename': '462.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 02:40:00 -0800 (PST)',
#              'Subject': 'Wed . Night scrimmage/practice'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 2, 47),
#  '_id': ObjectId('4f16fc97d1e2d32371003e33'),
#  'filename': '461.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 02:47:00 -0800 (PST)',
#              'Subject': 'Gore Priceless'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 2, 51),
#  '_id': ObjectId('4f16fc97d1e2d32371003e32'),
#  'filename': '460.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 02:51:00 -0800 (PST)',
#              'Subject': 'Re: Wed . Night scrimmage/practice'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 3, 0),
#  '_id': ObjectId('4f16fc97d1e2d32371003e30'),
#  'filename': '459.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 03:00:00 -0800 (PST)', 'Subject': ''}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 3, 11),
#  '_id': ObjectId('4f16fc97d1e2d32371003e2c'),
#  'filename': '455.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 03:11:00 -0800 (PST)',
#              'Subject': "Here's The Deal .......... Surprise Jamaican "
#                         'Vacation!'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 3, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e2f'),
#  'filename': '458.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 03:22:00 -0800 (PST)',
#              'Subject': 'fwd: FW: Fwd: Picture worth a thousand words'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 3, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e2e'),
#  'filename': '457.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 03:22:00 -0800 (PST)',
#              'Subject': 'Fwd: FW: Aggies Demand a Recount'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 5, 39),
#  '_id': ObjectId('4f16fc97d1e2d32371003e2d'),
#  'filename': '456.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 05:39:00 -0800 (PST)',
#              'Subject': 'instruct.jpg'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 6, 59),
#  '_id': ObjectId('4f16fc97d1e2d32371003e2b'),
#  'filename': '454.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 06:59:00 -0800 (PST)',
#              'Subject': 'Sorry, I keep getting these things.'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 7, 25),
#  '_id': ObjectId('4f16fc97d1e2d32371003e29'),
#  'filename': '452.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 07:25:00 -0800 (PST)',
#              'Subject': 'Re: check it out'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 7, 37),
#  '_id': ObjectId('4f16fc97d1e2d32371003e28'),
#  'filename': '451.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 07:37:00 -0800 (PST)',
#              'Subject': 'Re: Plays and other information'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 8, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e27'),
#  'filename': '450.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 08:22:00 -0800 (PST)',
#              'Subject': 'Re: Plays and other information'}}
# {'DateOfMessage': datetime.datetime(2000, 11, 14, 8, 32),
#  '_id': ObjectId('4f16fc97d1e2d32371003e2a'),
#  'filename': '453.',
#  'headers': {'Date': 'Tue, 14 Nov 2000 08:32:00 -0800 (PST)',
#              'Subject': '[cheatsheets] Brian Griese Injury'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 7, 18, 33),
#  '_id': ObjectId('4f16fc97d1e2d32371003e7f'),
#  'filename': '53.',
#  'headers': {'Date': 'Thu, 7 Dec 2000 18:33:00 -0800 (PST)',
#              'Subject': 'SFX Music | San Antonio Concert Update'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 8, 6, 17),
#  '_id': ObjectId('4f16fc97d1e2d32371003e5e'),
#  'filename': '50.',
#  'headers': {'Date': 'Fri, 8 Dec 2000 06:17:00 -0800 (PST)',
#              'Subject': 'The Democratic leadership is feeling the heat!'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 8, 7, 46),
#  '_id': ObjectId('4f16fc97d1e2d32371003e52'),
#  'filename': '49.',
#  'headers': {'Date': 'Fri, 8 Dec 2000 07:46:00 -0800 (PST)',
#              'Subject': 'Your Amazon.com order (#107-2036018-9394966)'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 8, 8, 53),
#  '_id': ObjectId('4f16fc97d1e2d32371003e8a'),
#  'filename': '54.',
#  'headers': {'Date': 'Fri, 8 Dec 2000 08:53:00 -0800 (PST)',
#              'Subject': 'SUPPLEMENTAL Weekend Outage Report for 12-8-00 '
#                         'through 12-11-00'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 8, 9, 19),
#  '_id': ObjectId('4f16fc97d1e2d32371003e74'),
#  'filename': '52.',
#  'headers': {'Date': 'Fri, 8 Dec 2000 09:19:00 -0800 (PST)',
#              'Subject': 'A&A Brown Bag'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 8, 9, 28),
#  '_id': ObjectId('4f16fc97d1e2d32371003e69'),
#  'filename': '51.',
#  'headers': {'Date': 'Fri, 8 Dec 2000 09:28:00 -0800 (PST)',
#              'Subject': 'Enron In Action 12.11.00'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 8, 21, 4),
#  '_id': ObjectId('4f16fc97d1e2d32371003e47'),
#  'filename': '48.',
#  'headers': {'Date': 'Fri, 8 Dec 2000 21:04:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for Y2KG 12/9/00'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 9, 1, 22),
#  '_id': ObjectId('4f16fc97d1e2d32371003e3c'),
#  'filename': '47.',
#  'headers': {'Date': 'Sat, 9 Dec 2000 01:22:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for Big E 12/9/00'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 9, 2, 27),
#  '_id': ObjectId('4f16fc97d1e2d32371003e31'),
#  'filename': '46.',
#  'headers': {'Date': 'Sat, 9 Dec 2000 02:27:00 -0800 (PST)',
#              'Subject': 'Commissioner.COM E-Reports for The Perfect League '
#                         '12/9/00'}}
# {'DateOfMessage': datetime.datetime(2000, 12, 13, 3, 3),
#  '_id': ObjectId('4f16fc97d1e2d32371003e5d'),
#  'filename': '5.',
#  'headers': {'Date': 'Wed, 13 Dec 2000 03:03:00 -0800 (PST)',
#              'Subject': 'INSIDE INVESTORAMA 12.13.00'}}

# %% [markdown]
# ### 5)
#
# Write a function which returns the percentage of emails sent on a weekend (i.e., Saturday and Sunday) as a `float` between 0 and 1. [6 points]

# %%
def get_percentage_sent_on_weekend(collection):
    """
    :param collection A PyMongo collection object
    :return A float between 0 and 1
    """    
    # YOUR CODE HERE
    
    pass

# %%
total_documents = messages_collection.count_documents({})

# %%
limit_stage = {
    '$limit': 100
}



project_stage = {
     '$project': { 'DateOfMessage': 
                      {'$dateFromString': { 'dateString' : 
                                           { '$rtrim': {'input': {'$substr': ['$headers.Date', 0, 25] }}}
                                          
                                          }
                      },
                        
                        'filename': 1,
                        'headers.Date': 1,
                 } 
}

project_stage2 = {
     '$project': { 'DateOfMessage': 1,
                    'filename': 1,
                    'headers.Date': 1,
                    'DayOfWeek': {
                        '$dayOfWeek': '$DateOfMessage'
                    }
                 } 
}

project_stage3 = {
     '$project': { 'DayOfWeek': 1,
                    'filename': 1,
                    'DayType': {
                        '$cond': { 'if': { '$in': [ "$DayOfWeek", [1, 7] ] }, "then": "weekend", 'else': 'weekday' }
                    }
                 } 
}

group_stage1 = {
    '$group': {
        '_id': '$DayType', 'count': {'$sum': 1}
    }
}

match_stage1 = {
    '$match': {
        '_id': 'weekend'
    }
}

project_stage4 = {
    '$project': {
        'percentage_weekend': { '$divide': ['$count', total_documents] }
    }
}




pipeline = [project_stage, project_stage2, project_stage3, group_stage1, match_stage1, project_stage4]

for doc in messages_collection.aggregate(pipeline):
    #pprint(doc['headers']['Date'][:-12])
    #pprint(datetime.strptime(doc['headers']['Date'][:-12], '%a, %d %b %Y %H:%M:%S'))
    
    pprint(doc)
# Out:
# {'_id': 'weekend', 'percentage_weekend': 0.0393}

# %%
limit_stage = {
    '$limit': 100
}

project_stage1 = {
     '$project': {
                     '_id': 0,
                     'Sent': '$headers.From',
                     'Received': ['$headers.To', '$headers.Cc'],
                     'To': '$headers.To',
                     'From': '$headers.From',
                     'Cc': '$headers.Cc'
         
                 } 
}

pipeline = [limit_stage, project_stage1]

for doc in messages_collection.aggregate(pipeline):
    pprint(doc)
# Out:
# {'From': 'michael.simmons@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'michael.simmons@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'michael.simmons@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'michael.simmons@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'Cc': 'jason.bass2@compaq.com',
#  'From': 'daphneco64@bigplanet.com',
#  'Received': ['eric.bass@enron.com', 'jason.bass2@compaq.com'],
#  'Sent': 'daphneco64@bigplanet.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'bryant@cheatsheets.net',
#  'Received': ['cheatsheets@egroups.com', None],
#  'Sent': 'bryant@cheatsheets.net',
#  'To': 'cheatsheets@egroups.com'}
# {'From': 'daphneco64@bigplanet.com',
#  'Received': ['lwbthemarine@bigplanet.com, jason.bass2@compaq.com, '
#               'eric.bass@enron.com, \r\n'
#               '\tchebert108@aol.com',
#               None],
#  'Sent': 'daphneco64@bigplanet.com',
#  'To': 'lwbthemarine@bigplanet.com, jason.bass2@compaq.com, '
#        'eric.bass@enron.com, \r\n'
#        '\tchebert108@aol.com'}
# {'From': 'steve.venturatos@enron.com',
#  'Received': ['jody.crook@enron.com, david.baumbach@enron.com, '
#               'kelly.lombardi@enron.com, \r\n'
#               '\tbryan.hull@enron.com, eric.bass@enron.com, '
#               'patrick.ryder@enron.com, \r\n'
#               '\tdenver.plachy@enron.com, yvette.connevey@enron.com, \r\n'
#               '\tpat.clynes@enron.com, daren.farmer@enron.com',
#               None],
#  'Sent': 'steve.venturatos@enron.com',
#  'To': 'jody.crook@enron.com, david.baumbach@enron.com, '
#        'kelly.lombardi@enron.com, \r\n'
#        '\tbryan.hull@enron.com, eric.bass@enron.com, '
#        'patrick.ryder@enron.com, \r\n'
#        '\tdenver.plachy@enron.com, yvette.connevey@enron.com, \r\n'
#        '\tpat.clynes@enron.com, daren.farmer@enron.com'}
# {'From': 'customers@travelnow.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'customers@travelnow.com',
#  'To': 'ebass@enron.com'}
# {'From': 'luis.mena@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'luis.mena@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'matthew.lenhart@enron.com',
#  'Received': ['chad.landry@enron.com, timothy.blanchard@enron.com, '
#               'bryan.hull@enron.com, \r\n'
#               '\teric.bass@enron.com, phillip.love@enron.com, \r\n'
#               '\tkenneth.shulklapper@enron.com, jay.reitmeyer@enron.com, \r\n'
#               '\ttori.kuykendall@enron.com, lisa.gillette@enron.com, \r\n'
#               '\tchrista.winfrey@enron.com',
#               None],
#  'Sent': 'matthew.lenhart@enron.com',
#  'To': 'chad.landry@enron.com, timothy.blanchard@enron.com, '
#        'bryan.hull@enron.com, \r\n'
#        '\teric.bass@enron.com, phillip.love@enron.com, \r\n'
#        '\tkenneth.shulklapper@enron.com, jay.reitmeyer@enron.com, \r\n'
#        '\ttori.kuykendall@enron.com, lisa.gillette@enron.com, \r\n'
#        '\tchrista.winfrey@enron.com'}
# {'From': 'shanna.husser@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'shanna.husser@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'Cc': 'webb.jennings@enron.com',
#  'From': 'michael.simmons@enron.com',
#  'Received': ['stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#               'luis.mena@enron.com, \r\n'
#               '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com',
#               'webb.jennings@enron.com'],
#  'Sent': 'michael.simmons@enron.com',
#  'To': 'stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#        'luis.mena@enron.com, \r\n'
#        '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com'}
# {'Cc': 'stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#        'luis.mena@enron.com, \r\n'
#        '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com',
#  'From': 'webb.jennings@enron.com',
#  'Received': ['michael.simmons@enron.com',
#               'stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#               'luis.mena@enron.com, \r\n'
#               '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com'],
#  'Sent': 'webb.jennings@enron.com',
#  'To': 'michael.simmons@enron.com'}
# {'From': 'jackson.logan@enron.com',
#  'Received': ['phillip.love@enron.com, eric.bass@enron.com, '
#               'darron.giron@enron.com, \r\n'
#               '\tvictor.guggenheim@enron.com',
#               None],
#  'Sent': 'jackson.logan@enron.com',
#  'To': 'phillip.love@enron.com, eric.bass@enron.com, '
#        'darron.giron@enron.com, \r\n'
#        '\tvictor.guggenheim@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'david.baumbach@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'david.baumbach@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'bthoskins@hotmail.com',
#  'Received': ['abamontb@slu.edu, allie_easton@yahoo.com, b2marina@aol.com, \r\n'
#               '\tmballases@hotmail.com, bsteinhart@yahoo.com, '
#               'ebass@enron.com, \r\n'
#               '\thcampos@enron.com, jessica_n_burke@hotmail.com, '
#               'katschott@usa.net, \r\n'
#               '\tleninej@hotmail.com, brian.hoskins@enron.com, '
#               'mpstan0@hotmail.com, \r\n'
#               '\tnina_bianchi@hotmail.com, stupor@home.com, \r\n'
#               '\troberto.martinez@enron.com',
#               None],
#  'Sent': 'bthoskins@hotmail.com',
#  'To': 'abamontb@slu.edu, allie_easton@yahoo.com, b2marina@aol.com, \r\n'
#        '\tmballases@hotmail.com, bsteinhart@yahoo.com, ebass@enron.com, \r\n'
#        '\thcampos@enron.com, jessica_n_burke@hotmail.com, '
#        'katschott@usa.net, \r\n'
#        '\tleninej@hotmail.com, brian.hoskins@enron.com, '
#        'mpstan0@hotmail.com, \r\n'
#        '\tnina_bianchi@hotmail.com, stupor@home.com, \r\n'
#        '\troberto.martinez@enron.com'}
# {'From': 'jason.bass2@compaq.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'jason.bass2@compaq.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'rebecca.torres@enron.com',
#  'Received': ['rebecca.torres@enron.com', None],
#  'Sent': 'rebecca.torres@enron.com',
#  'To': 'rebecca.torres@enron.com'}
# {'From': 'shanna.husser@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'shanna.husser@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'stacey.dempsey@enron.com',
#  'Received': ['craig.hall@enron.com, ryan.hinze@enron.com, '
#               'jennifer.martinez@enron.com, \r\n'
#               '\tjames.whitehead@enron.com, darren.maloney@enron.com, \r\n'
#               '\tcrystal.hyde@enron.com, benjamin.markey@enron.com, \r\n'
#               '\tgeorge.thomas@enron.com, catherine.clark@enron.com, \r\n'
#               '\tzaib.iqtidar@enron.com, chad.landry@enron.com, '
#               'chad.landry@enron.com, \r\n'
#               '\tmo.bawa@enron.com, john.massey@enron.com, '
#               'jonathon.pielop@enron.com, \r\n'
#               '\tbrent.dornier@enron.com, christa.winfrey@enron.com, \r\n'
#               '\takasha.redrick@enron.com, reza.rezaeian@enron.com, \r\n'
#               '\teric.scott@enron.com, kate.lucas@enron.com, '
#               'erin.willis@enron.com, \r\n'
#               '\tfarzad.farhangnia@enron.com, sarah.mulholland@enron.com, \r\n'
#               '\tmatthew.lenhart@enron.com, kenneth.shulklapper@enron.com, \r\n'
#               '\tkevin.ruscitti@enron.com, hector.campos@enron.com, \r\n'
#               '\tkarla.compean@enron.com, zal.masani@enron.com, \r\n'
#               '\tleonard.tham@enron.com, claire.broido@enron.com, \r\n'
#               '\tyvan.chaxel@enron.com, pearce.hammond@enron.com, \r\n'
#               '\telizabeth.howley@enron.com, usman.shaukat@enron.com, \r\n'
#               '\tmisti.day@enron.com, simone.rose@enron.com, '
#               'michelle.zhang@enron.com, \r\n'
#               '\tshilpa.chunchu@enron.com, daniel.graham@enron.com, \r\n'
#               '\tmolly.hellerman@enron.com, david.hunker@enron.com, \r\n'
#               '\talberto.jimenez@enron.com, jebong.lee@enron.com, \r\n'
#               '\tchetan.paipanandiker@enron.com, eva.rainer@enron.com, \r\n'
#               '\tcarlos.ruiz@enron.com, stephanie.segura@enron.com, \r\n'
#               '\trahul.seksaria@enron.com, michael.simmons@enron.com, \r\n'
#               '\timad.tareen@enron.com, todd.roten@enron.com, '
#               'chu.wang@enron.com, \r\n'
#               '\tchad.gronvold@enron.com, alton.jackson@enron.com, \r\n'
#               '\tgerardo.benitez@enron.com, ibrahim.qureishi@enron.com, \r\n'
#               '\tbret.scholtes@enron.com, marc.sabine@enron.com, \r\n'
#               '\tjason.seigal@enron.com, valter.stoiani@enron.com, \r\n'
#               '\tjennifer.reside@enron.com, michael.garberding@enron.com, \r\n'
#               '\tchris.herron@enron.com, ed.wood@enron.com, '
#               'petual.jeanmard@enron.com, \r\n'
#               '\tjohn.scarborough@enron.com, '
#               'jean-sebastien.fontaine@enron.com, \r\n'
#               '\tjason.althaus@enron.com, leonardo.pacheco@enron.com, \r\n'
#               '\tmario.cardoso@enron.com, jin.guo@enron.com, \r\n'
#               '\tselena.gonzalez@enron.com, matthew.jachimiak@enron.com, \r\n'
#               '\tkelly.mccoy@enron.com, michael.kolman@enron.com, '
#               'binh.pham@enron.com, \r\n'
#               '\tpeter.bennett@enron.com, angie.zeman@enron.com, \r\n'
#               '\tvictor.guggenheim@enron.com, alicia.perkins@enron.com, \r\n'
#               '\tchris.walker@enron.com, raimund.grube@enron.com, \r\n'
#               '\tstephen.plauche@enron.com, adnan.patel@enron.com, \r\n'
#               '\tross.prevatt@enron.com, israel.estrada@enron.com, \r\n'
#               '\tgaurav.babbar@enron.com, banu.ozcan@enron.com, \r\n'
#               '\tmilind.pasad@enron.com, claudio.ribeiro@enron.com, \r\n'
#               '\ttravis.winfrey@enron.com, gray.calvert@enron.com, \r\n'
#               '\tstephen.thome@enron.com, laura.wente@enron.com, \r\n'
#               '\tyvette.parker@enron.com, victor.browner@enron.com, \r\n'
#               '\twinston.cheng@enron.com, vicky.ha@enron.com, '
#               'nick.hiemstra@enron.com, \r\n'
#               '\tjohn.howton@enron.com, josephine.lin@enron.com, \r\n'
#               '\ttyrell.harrison@enron.com, todd.hattenbach@enron.com, \r\n'
#               '\tcharles.varnell@enron.com, lisa.gillette@enron.com, \r\n'
#               '\tjay.epstein@enron.com, jody.crook@enron.com, \r\n'
#               '\tmichael.benien@enron.com, daniel.falcone@enron.com, \r\n'
#               '\tjennifer.bagwell@enron.com, gabriel.monroy@enron.com, \r\n'
#               '\trobin.rodrigue@enron.com, michelle.waldhauser@enron.com, \r\n'
#               '\tpurvi.patel@enron.com, sscott5@enron.com, '
#               'greg.martin@enron.com, \r\n'
#               '\tjohn.weakly@enron.com, sheetal.patel@enron.com, \r\n'
#               '\tbrando.hayden@enron.com, seth.hurwitz@enron.com, \r\n'
#               '\tbryan.hull@enron.com, angelique.woods@enron.com, \r\n'
#               '\tryan.deane@enron.com, zeina.el-azzi@enron.com, \r\n'
#               '\tmichael.flanigan@enron.com, marsha.francis@enron.com, \r\n'
#               '\tjoe.gordon@enron.com, paul.gregory@enron.com, '
#               'amber.hamby@enron.com, \r\n'
#               '\tjonathan.hoff@enron.com, sean.keenan@enron.com, \r\n'
#               '\tdayem.khandker@enron.com, john.king@enron.com, \r\n'
#               '\tkelli.little@enron.com, stanton.ray@enron.com, '
#               'shahid.shah@enron.com, \r\n'
#               '\tying.soong@enron.com, ryan.synnott@enron.com, \r\n'
#               '\tbenjamin.thomason@enron.com, justyn.thompson@enron.com, \r\n'
#               '\tmiguel.vasquez@enron.com, jason.wiesepape@enron.com, \r\n'
#               '\tvirawan.yawapongsiri@enron.com, '
#               'michael.driscoll@enron.com, \r\n'
#               '\tchris.mallory@enron.com, cooper.richey@enron.com, \r\n'
#               '\tgeir.solberg@enron.com, jennifer.newbrough@enron.com, \r\n'
#               '\theather.alon@enron.com, eric.bass@enron.com, '
#               'erica.bess@enron.com, \r\n'
#               '\tevan.betzer@enron.com, harry.bucalo@enron.com, '
#               'hang.bui@enron.com, \r\n'
#               '\tmark.castiglione@enron.com, monika.causholli@enron.com, \r\n'
#               '\tbrandon.cavazos@enron.com, andy.chen@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com, teresa.dyar@enron.com, \r\n'
#               '\tdaniel.ferrell@enron.com, steve.gim@enron.com, '
#               'john.gordon@enron.com, \r\n'
#               '\tscott.griffin@enron.com, christian.hackett@enron.com, \r\n'
#               '\tbrian.hoskins@enron.com, avinash.jain@enron.com, \r\n'
#               '\tjolly.jose@enron.com, william.keeney@enron.com, \r\n'
#               '\tjoshua.koenig@enron.com, clement.lau@enron.com, \r\n'
#               '\tfatimata.liamidi@enron.com, homer.lin@enron.com, \r\n'
#               '\tatticus.lyon@enron.com, kelley.mcintyre@enron.com, \r\n'
#               '\travi.mujumdar@enron.com, kourtney.nelson@enron.com, \r\n'
#               '\tiris.ng@enron.com, sanjay.patel@enron.com, '
#               'shiraz.rehman@enron.com, \r\n'
#               '\tjustin.rostant@enron.com, anthony.sexton@enron.com, \r\n'
#               '\telizabeth.shim@enron.com, joseph.short@enron.com, \r\n'
#               '\tgauri.khokha@enron.com, carrie.southard@enron.com, \r\n'
#               '\tsarah.taylor@enron.com, maria.tefel@enron.com, '
#               'brandon.wax@enron.com, \r\n'
#               '\tlewis.worthy@enron.com, allan.wu@enron.com, '
#               'george.zivic@enron.com, \r\n'
#               '\tted.noble@enron.com, brogers2@enron.com, '
#               'gautam.gupta@enron.com, \r\n'
#               '\trussell.dyk@enron.com, wjennin@enron.com, '
#               'doug.sewell@enron.com, \r\n'
#               '\tlisa.connolly@enron.com, tara.piazze@enron.com, '
#               'chuck.ames@enron.com, \r\n'
#               '\tnate.blackburn@enron.com, sachin.gandhi@enron.com, '
#               'mog.heu@enron.com, \r\n'
#               '\tsabina.rank@enron.com, elizabeth.shim@enron.com, \r\n'
#               '\tmassimo.marolo@enron.com, vladi.pimenov@enron.com, \r\n'
#               '\tdamon.harvey@enron.com',
#               None],
#  'Sent': 'stacey.dempsey@enron.com',
#  'To': 'craig.hall@enron.com, ryan.hinze@enron.com, '
#        'jennifer.martinez@enron.com, \r\n'
#        '\tjames.whitehead@enron.com, darren.maloney@enron.com, \r\n'
#        '\tcrystal.hyde@enron.com, benjamin.markey@enron.com, \r\n'
#        '\tgeorge.thomas@enron.com, catherine.clark@enron.com, \r\n'
#        '\tzaib.iqtidar@enron.com, chad.landry@enron.com, '
#        'chad.landry@enron.com, \r\n'
#        '\tmo.bawa@enron.com, john.massey@enron.com, '
#        'jonathon.pielop@enron.com, \r\n'
#        '\tbrent.dornier@enron.com, christa.winfrey@enron.com, \r\n'
#        '\takasha.redrick@enron.com, reza.rezaeian@enron.com, \r\n'
#        '\teric.scott@enron.com, kate.lucas@enron.com, '
#        'erin.willis@enron.com, \r\n'
#        '\tfarzad.farhangnia@enron.com, sarah.mulholland@enron.com, \r\n'
#        '\tmatthew.lenhart@enron.com, kenneth.shulklapper@enron.com, \r\n'
#        '\tkevin.ruscitti@enron.com, hector.campos@enron.com, \r\n'
#        '\tkarla.compean@enron.com, zal.masani@enron.com, \r\n'
#        '\tleonard.tham@enron.com, claire.broido@enron.com, \r\n'
#        '\tyvan.chaxel@enron.com, pearce.hammond@enron.com, \r\n'
#        '\telizabeth.howley@enron.com, usman.shaukat@enron.com, \r\n'
#        '\tmisti.day@enron.com, simone.rose@enron.com, '
#        'michelle.zhang@enron.com, \r\n'
#        '\tshilpa.chunchu@enron.com, daniel.graham@enron.com, \r\n'
#        '\tmolly.hellerman@enron.com, david.hunker@enron.com, \r\n'
#        '\talberto.jimenez@enron.com, jebong.lee@enron.com, \r\n'
#        '\tchetan.paipanandiker@enron.com, eva.rainer@enron.com, \r\n'
#        '\tcarlos.ruiz@enron.com, stephanie.segura@enron.com, \r\n'
#        '\trahul.seksaria@enron.com, michael.simmons@enron.com, \r\n'
#        '\timad.tareen@enron.com, todd.roten@enron.com, chu.wang@enron.com, \r\n'
#        '\tchad.gronvold@enron.com, alton.jackson@enron.com, \r\n'
#        '\tgerardo.benitez@enron.com, ibrahim.qureishi@enron.com, \r\n'
#        '\tbret.scholtes@enron.com, marc.sabine@enron.com, \r\n'
#        '\tjason.seigal@enron.com, valter.stoiani@enron.com, \r\n'
#        '\tjennifer.reside@enron.com, michael.garberding@enron.com, \r\n'
#        '\tchris.herron@enron.com, ed.wood@enron.com, '
#        'petual.jeanmard@enron.com, \r\n'
#        '\tjohn.scarborough@enron.com, jean-sebastien.fontaine@enron.com, \r\n'
#        '\tjason.althaus@enron.com, leonardo.pacheco@enron.com, \r\n'
#        '\tmario.cardoso@enron.com, jin.guo@enron.com, \r\n'
#        '\tselena.gonzalez@enron.com, matthew.jachimiak@enron.com, \r\n'
#        '\tkelly.mccoy@enron.com, michael.kolman@enron.com, '
#        'binh.pham@enron.com, \r\n'
#        '\tpeter.bennett@enron.com, angie.zeman@enron.com, \r\n'
#        '\tvictor.guggenheim@enron.com, alicia.perkins@enron.com, \r\n'
#        '\tchris.walker@enron.com, raimund.grube@enron.com, \r\n'
#        '\tstephen.plauche@enron.com, adnan.patel@enron.com, \r\n'
#        '\tross.prevatt@enron.com, israel.estrada@enron.com, \r\n'
#        '\tgaurav.babbar@enron.com, banu.ozcan@enron.com, \r\n'
#        '\tmilind.pasad@enron.com, claudio.ribeiro@enron.com, \r\n'
#        '\ttravis.winfrey@enron.com, gray.calvert@enron.com, \r\n'
#        '\tstephen.thome@enron.com, laura.wente@enron.com, \r\n'
#        '\tyvette.parker@enron.com, victor.browner@enron.com, \r\n'
#        '\twinston.cheng@enron.com, vicky.ha@enron.com, '
#        'nick.hiemstra@enron.com, \r\n'
#        '\tjohn.howton@enron.com, josephine.lin@enron.com, \r\n'
#        '\ttyrell.harrison@enron.com, todd.hattenbach@enron.com, \r\n'
#        '\tcharles.varnell@enron.com, lisa.gillette@enron.com, \r\n'
#        '\tjay.epstein@enron.com, jody.crook@enron.com, \r\n'
#        '\tmichael.benien@enron.com, daniel.falcone@enron.com, \r\n'
#        '\tjennifer.bagwell@enron.com, gabriel.monroy@enron.com, \r\n'
#        '\trobin.rodrigue@enron.com, michelle.waldhauser@enron.com, \r\n'
#        '\tpurvi.patel@enron.com, sscott5@enron.com, greg.martin@enron.com, \r\n'
#        '\tjohn.weakly@enron.com, sheetal.patel@enron.com, \r\n'
#        '\tbrando.hayden@enron.com, seth.hurwitz@enron.com, \r\n'
#        '\tbryan.hull@enron.com, angelique.woods@enron.com, \r\n'
#        '\tryan.deane@enron.com, zeina.el-azzi@enron.com, \r\n'
#        '\tmichael.flanigan@enron.com, marsha.francis@enron.com, \r\n'
#        '\tjoe.gordon@enron.com, paul.gregory@enron.com, '
#        'amber.hamby@enron.com, \r\n'
#        '\tjonathan.hoff@enron.com, sean.keenan@enron.com, \r\n'
#        '\tdayem.khandker@enron.com, john.king@enron.com, \r\n'
#        '\tkelli.little@enron.com, stanton.ray@enron.com, '
#        'shahid.shah@enron.com, \r\n'
#        '\tying.soong@enron.com, ryan.synnott@enron.com, \r\n'
#        '\tbenjamin.thomason@enron.com, justyn.thompson@enron.com, \r\n'
#        '\tmiguel.vasquez@enron.com, jason.wiesepape@enron.com, \r\n'
#        '\tvirawan.yawapongsiri@enron.com, michael.driscoll@enron.com, \r\n'
#        '\tchris.mallory@enron.com, cooper.richey@enron.com, \r\n'
#        '\tgeir.solberg@enron.com, jennifer.newbrough@enron.com, \r\n'
#        '\theather.alon@enron.com, eric.bass@enron.com, '
#        'erica.bess@enron.com, \r\n'
#        '\tevan.betzer@enron.com, harry.bucalo@enron.com, '
#        'hang.bui@enron.com, \r\n'
#        '\tmark.castiglione@enron.com, monika.causholli@enron.com, \r\n'
#        '\tbrandon.cavazos@enron.com, andy.chen@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com, teresa.dyar@enron.com, \r\n'
#        '\tdaniel.ferrell@enron.com, steve.gim@enron.com, '
#        'john.gordon@enron.com, \r\n'
#        '\tscott.griffin@enron.com, christian.hackett@enron.com, \r\n'
#        '\tbrian.hoskins@enron.com, avinash.jain@enron.com, \r\n'
#        '\tjolly.jose@enron.com, william.keeney@enron.com, \r\n'
#        '\tjoshua.koenig@enron.com, clement.lau@enron.com, \r\n'
#        '\tfatimata.liamidi@enron.com, homer.lin@enron.com, \r\n'
#        '\tatticus.lyon@enron.com, kelley.mcintyre@enron.com, \r\n'
#        '\travi.mujumdar@enron.com, kourtney.nelson@enron.com, \r\n'
#        '\tiris.ng@enron.com, sanjay.patel@enron.com, '
#        'shiraz.rehman@enron.com, \r\n'
#        '\tjustin.rostant@enron.com, anthony.sexton@enron.com, \r\n'
#        '\telizabeth.shim@enron.com, joseph.short@enron.com, \r\n'
#        '\tgauri.khokha@enron.com, carrie.southard@enron.com, \r\n'
#        '\tsarah.taylor@enron.com, maria.tefel@enron.com, '
#        'brandon.wax@enron.com, \r\n'
#        '\tlewis.worthy@enron.com, allan.wu@enron.com, '
#        'george.zivic@enron.com, \r\n'
#        '\tted.noble@enron.com, brogers2@enron.com, gautam.gupta@enron.com, \r\n'
#        '\trussell.dyk@enron.com, wjennin@enron.com, doug.sewell@enron.com, \r\n'
#        '\tlisa.connolly@enron.com, tara.piazze@enron.com, '
#        'chuck.ames@enron.com, \r\n'
#        '\tnate.blackburn@enron.com, sachin.gandhi@enron.com, '
#        'mog.heu@enron.com, \r\n'
#        '\tsabina.rank@enron.com, elizabeth.shim@enron.com, \r\n'
#        '\tmassimo.marolo@enron.com, vladi.pimenov@enron.com, \r\n'
#        '\tdamon.harvey@enron.com'}
# {'From': 'special-offers-help@mail.southwest.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'special-offers-help@mail.southwest.com',
#  'To': 'ebass@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'office.chairman@enron.com',
#  'Received': ['all.worldwide@enron.com', None],
#  'Sent': 'office.chairman@enron.com',
#  'To': 'all.worldwide@enron.com'}
# {'From': 'hotdeals@bestfares.com',
#  'Received': ['hotdeals@mail.bestfares.net', None],
#  'Sent': 'hotdeals@bestfares.com',
#  'To': 'hotdeals@mail.bestfares.net'}
# {'From': 'enron.announcements@enron.com',
#  'Received': ['enron.states@enron.com', None],
#  'Sent': 'enron.announcements@enron.com',
#  'To': 'enron.states@enron.com'}
# {'From': 'bushnews@georgewbush.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'bushnews@georgewbush.com',
#  'To': 'ebass@enron.com'}
# {'Cc': 'eric.bass@enron.com, hector.campos@enron.com, shanna.husser@enron.com',
#  'From': 'lenine.jeganathan@enron.com',
#  'Received': ['brian.hoskins@enron.com',
#               'eric.bass@enron.com, hector.campos@enron.com, '
#               'shanna.husser@enron.com'],
#  'Sent': 'lenine.jeganathan@enron.com',
#  'To': 'brian.hoskins@enron.com'}
# {'Cc': 'eric.bass@enron.com, hector.campos@enron.com, shanna.husser@enron.com',
#  'From': 'brian.hoskins@enron.com',
#  'Received': ['lenine.jeganathan@enron.com',
#               'eric.bass@enron.com, hector.campos@enron.com, '
#               'shanna.husser@enron.com'],
#  'Sent': 'brian.hoskins@enron.com',
#  'To': 'lenine.jeganathan@enron.com'}
# {'Cc': 'eric.bass@enron.com, hector.campos@enron.com, '
#        'lenine.jeganathan@enron.com',
#  'From': 'brian.hoskins@enron.com',
#  'Received': ['shanna.husser@enron.com',
#               'eric.bass@enron.com, hector.campos@enron.com, '
#               'lenine.jeganathan@enron.com'],
#  'Sent': 'brian.hoskins@enron.com',
#  'To': 'shanna.husser@enron.com'}
# {'Cc': 'hector.campos@enron.com, eric.bass@enron.com, brian.hoskins@enron.com',
#  'From': 'lenine.jeganathan@enron.com',
#  'Received': ['shanna.husser@enron.com',
#               'hector.campos@enron.com, eric.bass@enron.com, '
#               'brian.hoskins@enron.com'],
#  'Sent': 'lenine.jeganathan@enron.com',
#  'To': 'shanna.husser@enron.com'}
# {'From': 'announce-list@sfx.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'announce-list@sfx.com',
#  'To': 'ebass@enron.com'}
# {'Cc': 'shanna.husser@enron.com, eric.bass@enron.com, '
#        'lenine.jeganathan@enron.com',
#  'From': 'hector.campos@enron.com',
#  'Received': ['brian.hoskins@enron.com',
#               'shanna.husser@enron.com, eric.bass@enron.com, '
#               'lenine.jeganathan@enron.com'],
#  'Sent': 'hector.campos@enron.com',
#  'To': 'brian.hoskins@enron.com'}
# {'Cc': 'eric.bass@enron.com, brian.hoskins@enron.com, '
#        'lenine.jeganathan@enron.com',
#  'From': 'shanna.husser@enron.com',
#  'Received': ['hector.campos@enron.com',
#               'eric.bass@enron.com, brian.hoskins@enron.com, '
#               'lenine.jeganathan@enron.com'],
#  'Sent': 'shanna.husser@enron.com',
#  'To': 'hector.campos@enron.com'}
# {'From': 'ftd.com@mail2.ftdi.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'ftd.com@mail2.ftdi.com',
#  'To': 'ebass@enron.com'}
# {'From': 'lwbthemarine@bigplanet.com',
#  'Received': ['daphneco64@bigplanet.com, daphneco64@yahoo.com, '
#               'jason.bass2@compaq.com, \r\n'
#               '\teric.bass@enron.com',
#               None],
#  'Sent': 'lwbthemarine@bigplanet.com',
#  'To': 'daphneco64@bigplanet.com, daphneco64@yahoo.com, '
#        'jason.bass2@compaq.com, \r\n'
#        '\teric.bass@enron.com'}
# {'From': 'daphneco64@bigplanet.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'daphneco64@bigplanet.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'bryant@cheatsheets.net',
#  'Received': ['cheatsheets@egroups.com', None],
#  'Sent': 'bryant@cheatsheets.net',
#  'To': 'cheatsheets@egroups.com'}
# {'From': 'brian.hoskins@enron.com',
#  'Received': ['eric.bass@enron.com, shanna.husser@enron.com, '
#               'hector.campos@enron.com, \r\n'
#               '\tlenine.jeganathan@enron.com',
#               None],
#  'Sent': 'brian.hoskins@enron.com',
#  'To': 'eric.bass@enron.com, shanna.husser@enron.com, '
#        'hector.campos@enron.com, \r\n'
#        '\tlenine.jeganathan@enron.com'}
# {'From': 'luis.mena@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'luis.mena@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'luis.mena@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'luis.mena@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'michael.simmons@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'michael.simmons@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'matthew.lenhart@enron.com',
#  'Received': ['jay.reitmeyer@enron.com, paul.lucci@enron.com, '
#               'kenneth.shulklapper@enron.com, \r\n'
#               '\ttimothy.blanchard@enron.com, chad.landry@enron.com, \r\n'
#               '\teric.bass@enron.com, bryan.hull@enron.com, '
#               'phillip.love@enron.com',
#               None],
#  'Sent': 'matthew.lenhart@enron.com',
#  'To': 'jay.reitmeyer@enron.com, paul.lucci@enron.com, '
#        'kenneth.shulklapper@enron.com, \r\n'
#        '\ttimothy.blanchard@enron.com, chad.landry@enron.com, \r\n'
#        '\teric.bass@enron.com, bryan.hull@enron.com, phillip.love@enron.com'}
# {'From': 'orders@amazon.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'orders@amazon.com',
#  'To': 'ebass@enron.com'}
# {'From': 'daphneco64@bigplanet.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'daphneco64@bigplanet.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'michael.simmons@enron.com',
#  'Received': ['stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#               'luis.mena@enron.com, \r\n'
#               '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com',
#               None],
#  'Sent': 'michael.simmons@enron.com',
#  'To': 'stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#        'luis.mena@enron.com, \r\n'
#        '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com'}
# {'From': 'lwbthemarine@bigplanet.com',
#  'Received': ['daphneco64@bigplanet.com, daphneco64@yahoo.com, '
#               'jason.bass2@compaq.com, \r\n'
#               '\teric.bass@enron.com',
#               None],
#  'Sent': 'lwbthemarine@bigplanet.com',
#  'To': 'daphneco64@bigplanet.com, daphneco64@yahoo.com, '
#        'jason.bass2@compaq.com, \r\n'
#        '\teric.bass@enron.com'}
# {'From': 'luis.mena@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'luis.mena@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'chris.gaskill@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'chris.gaskill@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'phillip.love@enron.com',
#  'Received': ['alove770@cs.com, dlove8847@aol.com, jimmy.simien@enron.com, \r\n'
#               '\tkevin.bosse@enron.com, eric.bass@enron.com, '
#               'cntrybr279@cs.com, \r\n'
#               '\tkeithcorbo@aol.com, james.love@msl.redstone.army.mil, \r\n'
#               '\tmihipolito@juno.com, rachel.m.bonilla@ac.com, \r\n'
#               '\tkathy_nuernberg@yahoo.com, kathie.smith@enron.com, \r\n'
#               '\tjmjaked@mindspring.com, mjillard@beaconelectric.com, \r\n'
#               '\ttarm27@texas.net, wax@ghg.net, blb1173@aol.com, '
#               'shane.dobbs@fctg.com',
#               None],
#  'Sent': 'phillip.love@enron.com',
#  'To': 'alove770@cs.com, dlove8847@aol.com, jimmy.simien@enron.com, \r\n'
#        '\tkevin.bosse@enron.com, eric.bass@enron.com, cntrybr279@cs.com, \r\n'
#        '\tkeithcorbo@aol.com, james.love@msl.redstone.army.mil, \r\n'
#        '\tmihipolito@juno.com, rachel.m.bonilla@ac.com, \r\n'
#        '\tkathy_nuernberg@yahoo.com, kathie.smith@enron.com, \r\n'
#        '\tjmjaked@mindspring.com, mjillard@beaconelectric.com, \r\n'
#        '\ttarm27@texas.net, wax@ghg.net, blb1173@aol.com, shane.dobbs@fctg.com'}
# {'From': 'lwbthemarine@bigplanet.com',
#  'Received': ['daphneco64@bigplanet.com, daphneco64@yahoo.com, '
#               'jason.bass2@compaq.com, \r\n'
#               '\teric.bass@enron.com',
#               None],
#  'Sent': 'lwbthemarine@bigplanet.com',
#  'To': 'daphneco64@bigplanet.com, daphneco64@yahoo.com, '
#        'jason.bass2@compaq.com, \r\n'
#        '\teric.bass@enron.com'}
# {'From': 'michael.simmons@enron.com',
#  'Received': ['stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#               'luis.mena@enron.com, \r\n'
#               '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com',
#               None],
#  'Sent': 'michael.simmons@enron.com',
#  'To': 'stephen.schwarzbach@enron.com, eric.bass@enron.com, '
#        'luis.mena@enron.com, \r\n'
#        '\tpaul.broderick@enron.com, sarah.goodpastor@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com'}
# {'From': 'jason.bass2@compaq.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'jason.bass2@compaq.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'newsletter@investorama.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'newsletter@investorama.com',
#  'To': 'ebass@enron.com'}
# {'Cc': 'michael.simmons@enron.com',
#  'From': 'luis.mena@enron.com',
#  'Received': ['eric.bass@enron.com', 'michael.simmons@enron.com'],
#  'Sent': 'luis.mena@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'info@electionintegrity2000.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'info@electionintegrity2000.com',
#  'To': 'ebass@enron.com'}
# {'From': 'bryan.hull@enron.com',
#  'Received': ['eric.bass@enron.com, matthew.lenhart@enron.com, '
#               'timothy.blanchard@enron.com',
#               None],
#  'Sent': 'bryan.hull@enron.com',
#  'To': 'eric.bass@enron.com, matthew.lenhart@enron.com, '
#        'timothy.blanchard@enron.com'}
# {'From': 'laura.harder@enron.com',
#  'Received': ['thomas.martin@enron.com, jim.schwieger@enron.com, '
#               'greg.mcclendon@enron.com, \r\n'
#               '\telsa.villarreal@enron.com, daren.farmer@enron.com, \r\n'
#               '\tcarey.metz@enron.com, danny.conner@enron.com, \r\n'
#               '\tedward.gottlob@enron.com, gary.lamphier@enron.com, \r\n'
#               '\tjanet.wallis@enron.com, lauri.allen@enron.com, '
#               'liz.bellamy@enron.com, \r\n'
#               '\teric.bass@enron.com, stacey.neuweiler@enron.com',
#               None],
#  'Sent': 'laura.harder@enron.com',
#  'To': 'thomas.martin@enron.com, jim.schwieger@enron.com, '
#        'greg.mcclendon@enron.com, \r\n'
#        '\telsa.villarreal@enron.com, daren.farmer@enron.com, \r\n'
#        '\tcarey.metz@enron.com, danny.conner@enron.com, \r\n'
#        '\tedward.gottlob@enron.com, gary.lamphier@enron.com, \r\n'
#        '\tjanet.wallis@enron.com, lauri.allen@enron.com, '
#        'liz.bellamy@enron.com, \r\n'
#        '\teric.bass@enron.com, stacey.neuweiler@enron.com'}
# {'From': 'shanna.husser@enron.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'shanna.husser@enron.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'ken.skilling@enron.com',
#  'Received': ['all.employees@enron.com', None],
#  'Sent': 'ken.skilling@enron.com',
#  'To': 'all.employees@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'lqcolombo@aol.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'lqcolombo@aol.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'bryant@cheatsheets.net',
#  'Received': ['cheatsheets@egroups.com', None],
#  'Sent': 'bryant@cheatsheets.net',
#  'To': 'cheatsheets@egroups.com'}
# {'From': 'stacey.dempsey@enron.com',
#  'Received': ['craig.hall@enron.com, ryan.hinze@enron.com, '
#               'jennifer.martinez@enron.com, \r\n'
#               '\tjames.whitehead@enron.com, darren.maloney@enron.com, \r\n'
#               '\tcrystal.hyde@enron.com, benjamin.markey@enron.com, \r\n'
#               '\tgeorge.thomas@enron.com, catherine.clark@enron.com, \r\n'
#               '\tzaib.iqtidar@enron.com, chad.landry@enron.com, '
#               'chad.landry@enron.com, \r\n'
#               '\tmo.bawa@enron.com, john.massey@enron.com, '
#               'jonathon.pielop@enron.com, \r\n'
#               '\tbrent.dornier@enron.com, christa.winfrey@enron.com, \r\n'
#               '\takasha.redrick@enron.com, reza.rezaeian@enron.com, \r\n'
#               '\teric.scott@enron.com, kate.lucas@enron.com, '
#               'erin.willis@enron.com, \r\n'
#               '\tfarzad.farhangnia@enron.com, sarah.mulholland@enron.com, \r\n'
#               '\tmatthew.lenhart@enron.com, kenneth.shulklapper@enron.com, \r\n'
#               '\tkevin.ruscitti@enron.com, hector.campos@enron.com, \r\n'
#               '\tkarla.compean@enron.com, zal.masani@enron.com, \r\n'
#               '\tleonard.tham@enron.com, claire.broido@enron.com, \r\n'
#               '\tyvan.chaxel@enron.com, pearce.hammond@enron.com, \r\n'
#               '\telizabeth.howley@enron.com, usman.shaukat@enron.com, \r\n'
#               '\tmisti.day@enron.com, simone.rose@enron.com, '
#               'michelle.zhang@enron.com, \r\n'
#               '\tshilpa.chunchu@enron.com, daniel.graham@enron.com, \r\n'
#               '\tmolly.hellerman@enron.com, david.hunker@enron.com, \r\n'
#               '\talberto.jimenez@enron.com, jebong.lee@enron.com, \r\n'
#               '\tchetan.paipanandiker@enron.com, eva.rainer@enron.com, \r\n'
#               '\tcarlos.ruiz@enron.com, stephanie.segura@enron.com, \r\n'
#               '\trahul.seksaria@enron.com, michael.simmons@enron.com, \r\n'
#               '\timad.tareen@enron.com, todd.roten@enron.com, '
#               'chu.wang@enron.com, \r\n'
#               '\tchad.gronvold@enron.com, alton.jackson@enron.com, \r\n'
#               '\tgerardo.benitez@enron.com, ibrahim.qureishi@enron.com, \r\n'
#               '\tbret.scholtes@enron.com, marc.sabine@enron.com, \r\n'
#               '\tjason.seigal@enron.com, valter.stoiani@enron.com, \r\n'
#               '\tjennifer.reside@enron.com, michael.garberding@enron.com, \r\n'
#               '\tchris.herron@enron.com, ed.wood@enron.com, '
#               'petual.jeanmard@enron.com, \r\n'
#               '\tjohn.scarborough@enron.com, '
#               'jean-sebastien.fontaine@enron.com, \r\n'
#               '\tjason.althaus@enron.com, leonardo.pacheco@enron.com, \r\n'
#               '\tmario.cardoso@enron.com, jin.guo@enron.com, \r\n'
#               '\tselena.gonzalez@enron.com, matthew.jachimiak@enron.com, \r\n'
#               '\tkelly.mccoy@enron.com, michael.kolman@enron.com, '
#               'binh.pham@enron.com, \r\n'
#               '\tpeter.bennett@enron.com, angie.zeman@enron.com, \r\n'
#               '\tvictor.guggenheim@enron.com, alicia.perkins@enron.com, \r\n'
#               '\tchris.walker@enron.com, raimund.grube@enron.com, \r\n'
#               '\tstephen.plauche@enron.com, adnan.patel@enron.com, \r\n'
#               '\tross.prevatt@enron.com, israel.estrada@enron.com, \r\n'
#               '\tgaurav.babbar@enron.com, banu.ozcan@enron.com, \r\n'
#               '\tmilind.pasad@enron.com, claudio.ribeiro@enron.com, \r\n'
#               '\ttravis.winfrey@enron.com, gray.calvert@enron.com, \r\n'
#               '\tstephen.thome@enron.com, laura.wente@enron.com, \r\n'
#               '\tyvette.parker@enron.com, victor.browner@enron.com, \r\n'
#               '\twinston.cheng@enron.com, vicky.ha@enron.com, '
#               'nick.hiemstra@enron.com, \r\n'
#               '\tjohn.howton@enron.com, josephine.lin@enron.com, \r\n'
#               '\ttyrell.harrison@enron.com, todd.hattenbach@enron.com, \r\n'
#               '\tcharles.varnell@enron.com, lisa.gillette@enron.com, \r\n'
#               '\tjay.epstein@enron.com, jody.crook@enron.com, \r\n'
#               '\tmichael.benien@enron.com, daniel.falcone@enron.com, \r\n'
#               '\tjennifer.bagwell@enron.com, gabriel.monroy@enron.com, \r\n'
#               '\trobin.rodrigue@enron.com, michelle.waldhauser@enron.com, \r\n'
#               '\tpurvi.patel@enron.com, sscott5@enron.com, '
#               'greg.martin@enron.com, \r\n'
#               '\tjohn.weakly@enron.com, sheetal.patel@enron.com, \r\n'
#               '\tbrando.hayden@enron.com, seth.hurwitz@enron.com, \r\n'
#               '\tbryan.hull@enron.com, angelique.woods@enron.com, \r\n'
#               '\tryan.deane@enron.com, zeina.el-azzi@enron.com, \r\n'
#               '\tmichael.flanigan@enron.com, marsha.francis@enron.com, \r\n'
#               '\tjoe.gordon@enron.com, paul.gregory@enron.com, '
#               'amber.hamby@enron.com, \r\n'
#               '\tjonathan.hoff@enron.com, sean.keenan@enron.com, \r\n'
#               '\tdayem.khandker@enron.com, john.king@enron.com, \r\n'
#               '\tkelli.little@enron.com, stanton.ray@enron.com, '
#               'shahid.shah@enron.com, \r\n'
#               '\tying.soong@enron.com, ryan.synnott@enron.com, \r\n'
#               '\tbenjamin.thomason@enron.com, justyn.thompson@enron.com, \r\n'
#               '\tmiguel.vasquez@enron.com, jason.wiesepape@enron.com, \r\n'
#               '\tvirawan.yawapongsiri@enron.com, '
#               'michael.driscoll@enron.com, \r\n'
#               '\tchris.mallory@enron.com, cooper.richey@enron.com, \r\n'
#               '\tgeir.solberg@enron.com, jennifer.newbrough@enron.com, \r\n'
#               '\theather.alon@enron.com, eric.bass@enron.com, '
#               'erica.bess@enron.com, \r\n'
#               '\tevan.betzer@enron.com, harry.bucalo@enron.com, '
#               'hang.bui@enron.com, \r\n'
#               '\tmark.castiglione@enron.com, monika.causholli@enron.com, \r\n'
#               '\tbrandon.cavazos@enron.com, andy.chen@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com, teresa.dyar@enron.com, \r\n'
#               '\tdaniel.ferrell@enron.com, steve.gim@enron.com, '
#               'john.gordon@enron.com, \r\n'
#               '\tscott.griffin@enron.com, christian.hackett@enron.com, \r\n'
#               '\tbrian.hoskins@enron.com, avinash.jain@enron.com, \r\n'
#               '\tjolly.jose@enron.com, william.keeney@enron.com, \r\n'
#               '\tjoshua.koenig@enron.com, clement.lau@enron.com, \r\n'
#               '\tfatimata.liamidi@enron.com, homer.lin@enron.com, \r\n'
#               '\tatticus.lyon@enron.com, kelley.mcintyre@enron.com, \r\n'
#               '\travi.mujumdar@enron.com, kourtney.nelson@enron.com, \r\n'
#               '\tiris.ng@enron.com, sanjay.patel@enron.com, '
#               'shiraz.rehman@enron.com, \r\n'
#               '\tjustin.rostant@enron.com, anthony.sexton@enron.com, \r\n'
#               '\telizabeth.shim@enron.com, joseph.short@enron.com, \r\n'
#               '\tgauri.khokha@enron.com, carrie.southard@enron.com, \r\n'
#               '\tsarah.taylor@enron.com, maria.tefel@enron.com, '
#               'brandon.wax@enron.com, \r\n'
#               '\tlewis.worthy@enron.com, allan.wu@enron.com, '
#               'george.zivic@enron.com, \r\n'
#               '\tted.noble@enron.com, brogers2@enron.com, '
#               'gautam.gupta@enron.com, \r\n'
#               '\trussell.dyk@enron.com, wjennin@enron.com, '
#               'doug.sewell@enron.com, \r\n'
#               '\tlisa.connolly@enron.com, tara.piazze@enron.com, '
#               'chuck.ames@enron.com, \r\n'
#               '\tnate.blackburn@enron.com, sachin.gandhi@enron.com, '
#               'mog.heu@enron.com, \r\n'
#               '\tsabina.rank@enron.com, elizabeth.shim@enron.com, \r\n'
#               '\tmassimo.marolo@enron.com, vladi.pimenov@enron.com, \r\n'
#               '\tdamon.harvey@enron.com',
#               None],
#  'Sent': 'stacey.dempsey@enron.com',
#  'To': 'craig.hall@enron.com, ryan.hinze@enron.com, '
#        'jennifer.martinez@enron.com, \r\n'
#        '\tjames.whitehead@enron.com, darren.maloney@enron.com, \r\n'
#        '\tcrystal.hyde@enron.com, benjamin.markey@enron.com, \r\n'
#        '\tgeorge.thomas@enron.com, catherine.clark@enron.com, \r\n'
#        '\tzaib.iqtidar@enron.com, chad.landry@enron.com, '
#        'chad.landry@enron.com, \r\n'
#        '\tmo.bawa@enron.com, john.massey@enron.com, '
#        'jonathon.pielop@enron.com, \r\n'
#        '\tbrent.dornier@enron.com, christa.winfrey@enron.com, \r\n'
#        '\takasha.redrick@enron.com, reza.rezaeian@enron.com, \r\n'
#        '\teric.scott@enron.com, kate.lucas@enron.com, '
#        'erin.willis@enron.com, \r\n'
#        '\tfarzad.farhangnia@enron.com, sarah.mulholland@enron.com, \r\n'
#        '\tmatthew.lenhart@enron.com, kenneth.shulklapper@enron.com, \r\n'
#        '\tkevin.ruscitti@enron.com, hector.campos@enron.com, \r\n'
#        '\tkarla.compean@enron.com, zal.masani@enron.com, \r\n'
#        '\tleonard.tham@enron.com, claire.broido@enron.com, \r\n'
#        '\tyvan.chaxel@enron.com, pearce.hammond@enron.com, \r\n'
#        '\telizabeth.howley@enron.com, usman.shaukat@enron.com, \r\n'
#        '\tmisti.day@enron.com, simone.rose@enron.com, '
#        'michelle.zhang@enron.com, \r\n'
#        '\tshilpa.chunchu@enron.com, daniel.graham@enron.com, \r\n'
#        '\tmolly.hellerman@enron.com, david.hunker@enron.com, \r\n'
#        '\talberto.jimenez@enron.com, jebong.lee@enron.com, \r\n'
#        '\tchetan.paipanandiker@enron.com, eva.rainer@enron.com, \r\n'
#        '\tcarlos.ruiz@enron.com, stephanie.segura@enron.com, \r\n'
#        '\trahul.seksaria@enron.com, michael.simmons@enron.com, \r\n'
#        '\timad.tareen@enron.com, todd.roten@enron.com, chu.wang@enron.com, \r\n'
#        '\tchad.gronvold@enron.com, alton.jackson@enron.com, \r\n'
#        '\tgerardo.benitez@enron.com, ibrahim.qureishi@enron.com, \r\n'
#        '\tbret.scholtes@enron.com, marc.sabine@enron.com, \r\n'
#        '\tjason.seigal@enron.com, valter.stoiani@enron.com, \r\n'
#        '\tjennifer.reside@enron.com, michael.garberding@enron.com, \r\n'
#        '\tchris.herron@enron.com, ed.wood@enron.com, '
#        'petual.jeanmard@enron.com, \r\n'
#        '\tjohn.scarborough@enron.com, jean-sebastien.fontaine@enron.com, \r\n'
#        '\tjason.althaus@enron.com, leonardo.pacheco@enron.com, \r\n'
#        '\tmario.cardoso@enron.com, jin.guo@enron.com, \r\n'
#        '\tselena.gonzalez@enron.com, matthew.jachimiak@enron.com, \r\n'
#        '\tkelly.mccoy@enron.com, michael.kolman@enron.com, '
#        'binh.pham@enron.com, \r\n'
#        '\tpeter.bennett@enron.com, angie.zeman@enron.com, \r\n'
#        '\tvictor.guggenheim@enron.com, alicia.perkins@enron.com, \r\n'
#        '\tchris.walker@enron.com, raimund.grube@enron.com, \r\n'
#        '\tstephen.plauche@enron.com, adnan.patel@enron.com, \r\n'
#        '\tross.prevatt@enron.com, israel.estrada@enron.com, \r\n'
#        '\tgaurav.babbar@enron.com, banu.ozcan@enron.com, \r\n'
#        '\tmilind.pasad@enron.com, claudio.ribeiro@enron.com, \r\n'
#        '\ttravis.winfrey@enron.com, gray.calvert@enron.com, \r\n'
#        '\tstephen.thome@enron.com, laura.wente@enron.com, \r\n'
#        '\tyvette.parker@enron.com, victor.browner@enron.com, \r\n'
#        '\twinston.cheng@enron.com, vicky.ha@enron.com, '
#        'nick.hiemstra@enron.com, \r\n'
#        '\tjohn.howton@enron.com, josephine.lin@enron.com, \r\n'
#        '\ttyrell.harrison@enron.com, todd.hattenbach@enron.com, \r\n'
#        '\tcharles.varnell@enron.com, lisa.gillette@enron.com, \r\n'
#        '\tjay.epstein@enron.com, jody.crook@enron.com, \r\n'
#        '\tmichael.benien@enron.com, daniel.falcone@enron.com, \r\n'
#        '\tjennifer.bagwell@enron.com, gabriel.monroy@enron.com, \r\n'
#        '\trobin.rodrigue@enron.com, michelle.waldhauser@enron.com, \r\n'
#        '\tpurvi.patel@enron.com, sscott5@enron.com, greg.martin@enron.com, \r\n'
#        '\tjohn.weakly@enron.com, sheetal.patel@enron.com, \r\n'
#        '\tbrando.hayden@enron.com, seth.hurwitz@enron.com, \r\n'
#        '\tbryan.hull@enron.com, angelique.woods@enron.com, \r\n'
#        '\tryan.deane@enron.com, zeina.el-azzi@enron.com, \r\n'
#        '\tmichael.flanigan@enron.com, marsha.francis@enron.com, \r\n'
#        '\tjoe.gordon@enron.com, paul.gregory@enron.com, '
#        'amber.hamby@enron.com, \r\n'
#        '\tjonathan.hoff@enron.com, sean.keenan@enron.com, \r\n'
#        '\tdayem.khandker@enron.com, john.king@enron.com, \r\n'
#        '\tkelli.little@enron.com, stanton.ray@enron.com, '
#        'shahid.shah@enron.com, \r\n'
#        '\tying.soong@enron.com, ryan.synnott@enron.com, \r\n'
#        '\tbenjamin.thomason@enron.com, justyn.thompson@enron.com, \r\n'
#        '\tmiguel.vasquez@enron.com, jason.wiesepape@enron.com, \r\n'
#        '\tvirawan.yawapongsiri@enron.com, michael.driscoll@enron.com, \r\n'
#        '\tchris.mallory@enron.com, cooper.richey@enron.com, \r\n'
#        '\tgeir.solberg@enron.com, jennifer.newbrough@enron.com, \r\n'
#        '\theather.alon@enron.com, eric.bass@enron.com, '
#        'erica.bess@enron.com, \r\n'
#        '\tevan.betzer@enron.com, harry.bucalo@enron.com, '
#        'hang.bui@enron.com, \r\n'
#        '\tmark.castiglione@enron.com, monika.causholli@enron.com, \r\n'
#        '\tbrandon.cavazos@enron.com, andy.chen@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com, teresa.dyar@enron.com, \r\n'
#        '\tdaniel.ferrell@enron.com, steve.gim@enron.com, '
#        'john.gordon@enron.com, \r\n'
#        '\tscott.griffin@enron.com, christian.hackett@enron.com, \r\n'
#        '\tbrian.hoskins@enron.com, avinash.jain@enron.com, \r\n'
#        '\tjolly.jose@enron.com, william.keeney@enron.com, \r\n'
#        '\tjoshua.koenig@enron.com, clement.lau@enron.com, \r\n'
#        '\tfatimata.liamidi@enron.com, homer.lin@enron.com, \r\n'
#        '\tatticus.lyon@enron.com, kelley.mcintyre@enron.com, \r\n'
#        '\travi.mujumdar@enron.com, kourtney.nelson@enron.com, \r\n'
#        '\tiris.ng@enron.com, sanjay.patel@enron.com, '
#        'shiraz.rehman@enron.com, \r\n'
#        '\tjustin.rostant@enron.com, anthony.sexton@enron.com, \r\n'
#        '\telizabeth.shim@enron.com, joseph.short@enron.com, \r\n'
#        '\tgauri.khokha@enron.com, carrie.southard@enron.com, \r\n'
#        '\tsarah.taylor@enron.com, maria.tefel@enron.com, '
#        'brandon.wax@enron.com, \r\n'
#        '\tlewis.worthy@enron.com, allan.wu@enron.com, '
#        'george.zivic@enron.com, \r\n'
#        '\tted.noble@enron.com, brogers2@enron.com, gautam.gupta@enron.com, \r\n'
#        '\trussell.dyk@enron.com, wjennin@enron.com, doug.sewell@enron.com, \r\n'
#        '\tlisa.connolly@enron.com, tara.piazze@enron.com, '
#        'chuck.ames@enron.com, \r\n'
#        '\tnate.blackburn@enron.com, sachin.gandhi@enron.com, '
#        'mog.heu@enron.com, \r\n'
#        '\tsabina.rank@enron.com, elizabeth.shim@enron.com, \r\n'
#        '\tmassimo.marolo@enron.com, vladi.pimenov@enron.com, \r\n'
#        '\tdamon.harvey@enron.com'}
# {'From': 'bushnews@georgewbush.com',
#  'Received': ['ebass@enron.com', None],
# ...
#               '\ttyrell.harrison@enron.com, todd.hattenbach@enron.com, \r\n'
#               '\tcharles.varnell@enron.com, lisa.gillette@enron.com, \r\n'
#               '\tjay.epstein@enron.com, jody.crook@enron.com, \r\n'
#               '\tmichael.benien@enron.com, daniel.falcone@enron.com, \r\n'
#               '\tjennifer.bagwell@enron.com, gabriel.monroy@enron.com, \r\n'
#               '\trobin.rodrigue@enron.com, michelle.waldhauser@enron.com, \r\n'
#               '\tpurvi.patel@enron.com, sscott5@enron.com, '
#               'greg.martin@enron.com, \r\n'
#               '\tjohn.weakly@enron.com, sheetal.patel@enron.com, \r\n'
#               '\tbrando.hayden@enron.com, seth.hurwitz@enron.com, \r\n'
#               '\tbryan.hull@enron.com, angelique.woods@enron.com, \r\n'
#               '\tryan.deane@enron.com, zeina.el-azzi@enron.com, \r\n'
#               '\tmichael.flanigan@enron.com, marsha.francis@enron.com, \r\n'
#               '\tjoe.gordon@enron.com, paul.gregory@enron.com, '
#               'amber.hamby@enron.com, \r\n'
#               '\tjonathan.hoff@enron.com, sean.keenan@enron.com, \r\n'
#               '\tdayem.khandker@enron.com, john.king@enron.com, \r\n'
#               '\tkelli.little@enron.com, stanton.ray@enron.com, '
#               'shahid.shah@enron.com, \r\n'
#               '\tying.soong@enron.com, ryan.synnott@enron.com, \r\n'
#               '\tbenjamin.thomason@enron.com, justyn.thompson@enron.com, \r\n'
#               '\tmiguel.vasquez@enron.com, jason.wiesepape@enron.com, \r\n'
#               '\tvirawan.yawapongsiri@enron.com, '
#               'michael.driscoll@enron.com, \r\n'
#               '\tchris.mallory@enron.com, cooper.richey@enron.com, \r\n'
#               '\tgeir.solberg@enron.com, jennifer.newbrough@enron.com, \r\n'
#               '\theather.alon@enron.com, eric.bass@enron.com, '
#               'erica.bess@enron.com, \r\n'
#               '\tevan.betzer@enron.com, harry.bucalo@enron.com, '
#               'hang.bui@enron.com, \r\n'
#               '\tmark.castiglione@enron.com, monika.causholli@enron.com, \r\n'
#               '\tbrandon.cavazos@enron.com, andy.chen@enron.com, \r\n'
#               '\tchristopher.chenoweth@enron.com, teresa.dyar@enron.com, \r\n'
#               '\tdaniel.ferrell@enron.com, steve.gim@enron.com, '
#               'john.gordon@enron.com, \r\n'
#               '\tscott.griffin@enron.com, christian.hackett@enron.com, \r\n'
#               '\tbrian.hoskins@enron.com, avinash.jain@enron.com, \r\n'
#               '\tjolly.jose@enron.com, william.keeney@enron.com, \r\n'
#               '\tjoshua.koenig@enron.com, clement.lau@enron.com, \r\n'
#               '\tfatimata.liamidi@enron.com, homer.lin@enron.com, \r\n'
#               '\tatticus.lyon@enron.com, kelley.mcintyre@enron.com, \r\n'
#               '\travi.mujumdar@enron.com, kourtney.nelson@enron.com, \r\n'
#               '\tiris.ng@enron.com, sanjay.patel@enron.com, '
#               'shiraz.rehman@enron.com, \r\n'
#               '\tjustin.rostant@enron.com, anthony.sexton@enron.com, \r\n'
#               '\telizabeth.shim@enron.com, joseph.short@enron.com, \r\n'
#               '\tgauri.khokha@enron.com, carrie.southard@enron.com, \r\n'
#               '\tsarah.taylor@enron.com, maria.tefel@enron.com, '
#               'brandon.wax@enron.com, \r\n'
#               '\tlewis.worthy@enron.com, allan.wu@enron.com, '
#               'george.zivic@enron.com, \r\n'
#               '\tted.noble@enron.com, brogers2@enron.com, '
#               'gautam.gupta@enron.com, \r\n'
#               '\trussell.dyk@enron.com, wjennin@enron.com, '
#               'doug.sewell@enron.com, \r\n'
#               '\tlisa.connolly@enron.com, tara.piazze@enron.com, '
#               'chuck.ames@enron.com, \r\n'
#               '\tnate.blackburn@enron.com, sachin.gandhi@enron.com, '
#               'mog.heu@enron.com, \r\n'
#               '\tsabina.rank@enron.com, elizabeth.shim@enron.com, \r\n'
#               '\tmassimo.marolo@enron.com, vladi.pimenov@enron.com, \r\n'
#               '\tdamon.harvey@enron.com, hector.alviar@enron.com, \r\n'
#               '\tjoana.ryan.bekerman@enron.com',
#               None],
#  'Sent': 'tom.wilbeck@enron.com',
#  'To': 'craig.hall@enron.com, ryan.hinze@enron.com, '
#        'jennifer.martinez@enron.com, \r\n'
#        '\tjames.whitehead@enron.com, darren.maloney@enron.com, \r\n'
#        '\tcrystal.hyde@enron.com, benjamin.markey@enron.com, \r\n'
#        '\tgeorge.thomas@enron.com, catherine.clark@enron.com, \r\n'
#        '\tzaib.iqtidar@enron.com, chad.landry@enron.com, '
#        'chad.landry@enron.com, \r\n'
#        '\tmo.bawa@enron.com, john.massey@enron.com, '
#        'jonathon.pielop@enron.com, \r\n'
#        '\tbrent.dornier@enron.com, christa.winfrey@enron.com, \r\n'
#        '\takasha.redrick@enron.com, reza.rezaeian@enron.com, \r\n'
#        '\teric.scott@enron.com, kate.lucas@enron.com, '
#        'erin.willis@enron.com, \r\n'
#        '\tfarzad.farhangnia@enron.com, sarah.mulholland@enron.com, \r\n'
#        '\tmatthew.lenhart@enron.com, kenneth.shulklapper@enron.com, \r\n'
#        '\tkevin.ruscitti@enron.com, hector.campos@enron.com, \r\n'
#        '\tkarla.compean@enron.com, zal.masani@enron.com, \r\n'
#        '\tleonard.tham@enron.com, claire.broido@enron.com, \r\n'
#        '\tyvan.chaxel@enron.com, pearce.hammond@enron.com, \r\n'
#        '\telizabeth.howley@enron.com, usman.shaukat@enron.com, \r\n'
#        '\tmisti.day@enron.com, simone.rose@enron.com, '
#        'michelle.zhang@enron.com, \r\n'
#        '\tshilpa.chunchu@enron.com, daniel.graham@enron.com, \r\n'
#        '\tmolly.hellerman@enron.com, david.hunker@enron.com, \r\n'
#        '\talberto.jimenez@enron.com, jebong.lee@enron.com, \r\n'
#        '\tchetan.paipanandiker@enron.com, eva.rainer@enron.com, \r\n'
#        '\tcarlos.ruiz@enron.com, stephanie.segura@enron.com, \r\n'
#        '\trahul.seksaria@enron.com, michael.simmons@enron.com, \r\n'
#        '\timad.tareen@enron.com, todd.roten@enron.com, chu.wang@enron.com, \r\n'
#        '\tchad.gronvold@enron.com, alton.jackson@enron.com, \r\n'
#        '\tgerardo.benitez@enron.com, ibrahim.qureishi@enron.com, \r\n'
#        '\tbret.scholtes@enron.com, marc.sabine@enron.com, \r\n'
#        '\tjason.seigal@enron.com, valter.stoiani@enron.com, \r\n'
#        '\tjennifer.reside@enron.com, michael.garberding@enron.com, \r\n'
#        '\tchris.herron@enron.com, ed.wood@enron.com, '
#        'petual.jeanmard@enron.com, \r\n'
#        '\tjohn.scarborough@enron.com, jean-sebastien.fontaine@enron.com, \r\n'
#        '\tjason.althaus@enron.com, leonardo.pacheco@enron.com, \r\n'
#        '\tmario.cardoso@enron.com, jin.guo@enron.com, \r\n'
#        '\tselena.gonzalez@enron.com, matthew.jachimiak@enron.com, \r\n'
#        '\tkelly.mccoy@enron.com, michael.kolman@enron.com, '
#        'binh.pham@enron.com, \r\n'
#        '\tpeter.bennett@enron.com, angie.zeman@enron.com, \r\n'
#        '\tvictor.guggenheim@enron.com, alicia.perkins@enron.com, \r\n'
#        '\tchris.walker@enron.com, raimund.grube@enron.com, \r\n'
#        '\tstephen.plauche@enron.com, adnan.patel@enron.com, \r\n'
#        '\tross.prevatt@enron.com, israel.estrada@enron.com, \r\n'
#        '\tgaurav.babbar@enron.com, banu.ozcan@enron.com, \r\n'
#        '\tmilind.pasad@enron.com, claudio.ribeiro@enron.com, \r\n'
#        '\ttravis.winfrey@enron.com, gray.calvert@enron.com, \r\n'
#        '\tstephen.thome@enron.com, laura.wente@enron.com, \r\n'
#        '\tyvette.parker@enron.com, victor.browner@enron.com, \r\n'
#        '\twinston.cheng@enron.com, vicky.ha@enron.com, '
#        'nick.hiemstra@enron.com, \r\n'
#        '\tjohn.howton@enron.com, josephine.lin@enron.com, \r\n'
#        '\ttyrell.harrison@enron.com, todd.hattenbach@enron.com, \r\n'
#        '\tcharles.varnell@enron.com, lisa.gillette@enron.com, \r\n'
#        '\tjay.epstein@enron.com, jody.crook@enron.com, \r\n'
#        '\tmichael.benien@enron.com, daniel.falcone@enron.com, \r\n'
#        '\tjennifer.bagwell@enron.com, gabriel.monroy@enron.com, \r\n'
#        '\trobin.rodrigue@enron.com, michelle.waldhauser@enron.com, \r\n'
#        '\tpurvi.patel@enron.com, sscott5@enron.com, greg.martin@enron.com, \r\n'
#        '\tjohn.weakly@enron.com, sheetal.patel@enron.com, \r\n'
#        '\tbrando.hayden@enron.com, seth.hurwitz@enron.com, \r\n'
#        '\tbryan.hull@enron.com, angelique.woods@enron.com, \r\n'
#        '\tryan.deane@enron.com, zeina.el-azzi@enron.com, \r\n'
#        '\tmichael.flanigan@enron.com, marsha.francis@enron.com, \r\n'
#        '\tjoe.gordon@enron.com, paul.gregory@enron.com, '
#        'amber.hamby@enron.com, \r\n'
#        '\tjonathan.hoff@enron.com, sean.keenan@enron.com, \r\n'
#        '\tdayem.khandker@enron.com, john.king@enron.com, \r\n'
#        '\tkelli.little@enron.com, stanton.ray@enron.com, '
#        'shahid.shah@enron.com, \r\n'
#        '\tying.soong@enron.com, ryan.synnott@enron.com, \r\n'
#        '\tbenjamin.thomason@enron.com, justyn.thompson@enron.com, \r\n'
#        '\tmiguel.vasquez@enron.com, jason.wiesepape@enron.com, \r\n'
#        '\tvirawan.yawapongsiri@enron.com, michael.driscoll@enron.com, \r\n'
#        '\tchris.mallory@enron.com, cooper.richey@enron.com, \r\n'
#        '\tgeir.solberg@enron.com, jennifer.newbrough@enron.com, \r\n'
#        '\theather.alon@enron.com, eric.bass@enron.com, '
#        'erica.bess@enron.com, \r\n'
#        '\tevan.betzer@enron.com, harry.bucalo@enron.com, '
#        'hang.bui@enron.com, \r\n'
#        '\tmark.castiglione@enron.com, monika.causholli@enron.com, \r\n'
#        '\tbrandon.cavazos@enron.com, andy.chen@enron.com, \r\n'
#        '\tchristopher.chenoweth@enron.com, teresa.dyar@enron.com, \r\n'
#        '\tdaniel.ferrell@enron.com, steve.gim@enron.com, '
#        'john.gordon@enron.com, \r\n'
#        '\tscott.griffin@enron.com, christian.hackett@enron.com, \r\n'
#        '\tbrian.hoskins@enron.com, avinash.jain@enron.com, \r\n'
#        '\tjolly.jose@enron.com, william.keeney@enron.com, \r\n'
#        '\tjoshua.koenig@enron.com, clement.lau@enron.com, \r\n'
#        '\tfatimata.liamidi@enron.com, homer.lin@enron.com, \r\n'
#        '\tatticus.lyon@enron.com, kelley.mcintyre@enron.com, \r\n'
#        '\travi.mujumdar@enron.com, kourtney.nelson@enron.com, \r\n'
#        '\tiris.ng@enron.com, sanjay.patel@enron.com, '
#        'shiraz.rehman@enron.com, \r\n'
#        '\tjustin.rostant@enron.com, anthony.sexton@enron.com, \r\n'
#        '\telizabeth.shim@enron.com, joseph.short@enron.com, \r\n'
#        '\tgauri.khokha@enron.com, carrie.southard@enron.com, \r\n'
#        '\tsarah.taylor@enron.com, maria.tefel@enron.com, '
#        'brandon.wax@enron.com, \r\n'
#        '\tlewis.worthy@enron.com, allan.wu@enron.com, '
#        'george.zivic@enron.com, \r\n'
#        '\tted.noble@enron.com, brogers2@enron.com, gautam.gupta@enron.com, \r\n'
#        '\trussell.dyk@enron.com, wjennin@enron.com, doug.sewell@enron.com, \r\n'
#        '\tlisa.connolly@enron.com, tara.piazze@enron.com, '
#        'chuck.ames@enron.com, \r\n'
#        '\tnate.blackburn@enron.com, sachin.gandhi@enron.com, '
#        'mog.heu@enron.com, \r\n'
#        '\tsabina.rank@enron.com, elizabeth.shim@enron.com, \r\n'
#        '\tmassimo.marolo@enron.com, vladi.pimenov@enron.com, \r\n'
#        '\tdamon.harvey@enron.com, hector.alviar@enron.com, \r\n'
#        '\tjoana.ryan.bekerman@enron.com'}
# {'From': 'enron.announcements@enron.com',
#  'Received': ['houston.report@enron.com', None],
#  'Sent': 'enron.announcements@enron.com',
#  'To': 'houston.report@enron.com'}
# {'From': 'announce-list@sfx.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'announce-list@sfx.com',
#  'To': 'ebass@enron.com'}
# {'Cc': "o'neal.winfree@enron.com, eric.bass@enron.com, "
#        'matthew.lenhart@enron.com, \r\n'
#        '\tyvette.connevey@enron.com, paul.lucci@enron.com, \r\n'
#        '\tbryan.hull@enron.com, harry.bucalo@enron.com',
#  'From': 'michael.walters@enron.com',
#  'Received': ['david.baumbach@enron.com, julie.meyers@enron.com, '
#               'william.kelly@enron.com, \r\n'
#               '\tpatrick.ryder@enron.com, denver.plachy@enron.com, \r\n'
#               '\teddie.janzen@enron.com, mark.mccoy@enron.com, '
#               'jody.crook@enron.com',
#               "o'neal.winfree@enron.com, eric.bass@enron.com, "
#               'matthew.lenhart@enron.com, \r\n'
#               '\tyvette.connevey@enron.com, paul.lucci@enron.com, \r\n'
#               '\tbryan.hull@enron.com, harry.bucalo@enron.com'],
#  'Sent': 'michael.walters@enron.com',
#  'To': 'david.baumbach@enron.com, julie.meyers@enron.com, '
#        'william.kelly@enron.com, \r\n'
#        '\tpatrick.ryder@enron.com, denver.plachy@enron.com, \r\n'
#        '\teddie.janzen@enron.com, mark.mccoy@enron.com, jody.crook@enron.com'}
# {'From': 'bushnews@georgewbush.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'bushnews@georgewbush.com',
#  'To': 'ebass@enron.com'}
# {'From': 'announce-list@sfx.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'announce-list@sfx.com',
#  'To': 'ebass@enron.com'}
# {'From': 'enron.announcement@enron.com',
#  'Received': ['ect.frankfurt@enron.com, ect.helsinki@enron.com, '
#               'ect.houston@enron.com, \r\n'
#               '\tect.london@enron.com, ect.madrid@enron.com, '
#               'ect.moscow@enron.com, \r\n'
#               '\tect.oslo@enron.com, ect.singapore@enron.com, '
#               'ect.stockholm@enron.com, \r\n'
#               '\tect.zurich@enron.com',
#               None],
#  'Sent': 'enron.announcement@enron.com',
#  'To': 'ect.frankfurt@enron.com, ect.helsinki@enron.com, '
#        'ect.houston@enron.com, \r\n'
#        '\tect.london@enron.com, ect.madrid@enron.com, '
#        'ect.moscow@enron.com, \r\n'
#        '\tect.oslo@enron.com, ect.singapore@enron.com, '
#        'ect.stockholm@enron.com, \r\n'
#        '\tect.zurich@enron.com'}
# {'From': 'brian.hoskins@enron.com',
#  'Received': ['allison.easton@enron.com, hector.campos@enron.com, '
#               'eric.bass@enron.com, \r\n'
#               '\tlenine.jeganathan@enron.com',
#               None],
#  'Sent': 'brian.hoskins@enron.com',
#  'To': 'allison.easton@enron.com, hector.campos@enron.com, '
#        'eric.bass@enron.com, \r\n'
#        '\tlenine.jeganathan@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com',
#  'To': 'ebass@enron.com'}
# {'From': 'lwbthemarine@bigplanet.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'lwbthemarine@bigplanet.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'shanna.husser@enron.com',
#  'Received': ['eric.bass@enron.com, lildaigs@aol.com, staci@mcgarr.com', None],
#  'Sent': 'shanna.husser@enron.com',
#  'To': 'eric.bass@enron.com, lildaigs@aol.com, staci@mcgarr.com'}
# {'From': 'bryant@cheatsheets.net',
#  'Received': ['cheatsheets@egroups.com', None],
#  'Sent': 'bryant@cheatsheets.net',
#  'To': 'cheatsheets@egroups.com'}
# {'From': 'ebass@enron.com',
#  'Received': ['ebass@enron.com', None],
#  'Sent': 'ebass@enron.com',
#  'To': 'ebass@enron.com'}
# {'From': 'daphneco64@bigplanet.com',
#  'Received': ['eric.bass@enron.com', None],
#  'Sent': 'daphneco64@bigplanet.com',
#  'To': 'eric.bass@enron.com'}
# {'From': 'shanna.husser@enron.com',
#  'Received': ['eric.bass@enron.com, ccampbel@tosco.com, lildaigs@aol.com, \r\n'
#               '\tjason.sharp@enron.com, staci@mcgarr.com',
#               None],
#  'Sent': 'shanna.husser@enron.com',
#  'To': 'eric.bass@enron.com, ccampbel@tosco.com, lildaigs@aol.com, \r\n'
#        '\tjason.sharp@enron.com, staci@mcgarr.com'}
# {'From': 'matt.pena@enron.com',
#  'Received': ['unify.group@enron.com', None],
#  'Sent': 'matt.pena@enron.com',
#  'To': 'unify.group@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'enron.announcements@enron.com',
#  'Received': ['houston.report@enron.com', None],
#  'Sent': 'enron.announcements@enron.com',
#  'To': 'houston.report@enron.com'}
# {'From': 'noreply@ccomad3.uu.commissioner.com',
#  'Received': [None, None],
#  'Sent': 'noreply@ccomad3.uu.commissioner.com'}
# {'From': 'matt.pena@enron.com',
#  'Received': ['unify.group@enron.com', None],
#  'Sent': 'matt.pena@enron.com',
#  'To': 'unify.group@enron.com'}

# %%
from_data = []
to_data = []

from_emails = []
to_emails = []

limit_stage = {
    '$limit': 10
}

project_stage1 = {
     '$project': {
                     '_id': 0,
                     'Received_by': ['$headers.To', '$headers.Cc'],
                     'Sent_by': '$headers.From',
                 } 
}

unwind_stage1 = {
    '$unwind': {'path': '$Received_by', 'preserveNullAndEmptyArrays': True}
}

project_stage2 = {
    '$project': {
                     'Sent_by': 1,
                     'Received_by': {'$split': ['$Received_by', ', ']}
                     
                 } 
}

unwind_stage2 = {
    '$unwind': {'path': '$Received_by', 'preserveNullAndEmptyArrays': True}
}



project_stage3 = {
    '$project': {
        'Received_by': {'$trim': {'input': '$Received_by'}},
        'Sent_by': 1
        
    }
}

match_stage1 = {
    '$match': {
        'Received_by': {'$ne': None}
    }
}

# grouping users : To

group_stage1 = {
    '$group': { 
        '_id': '$Received_by',
        'count_to': {'$sum': 1}          
              }
}



# grouping users: From

group_stage2 = {
    '$group': { 
        '_id': '$Sent_by',
        'count_from': {'$sum': 1}          
              }
}



pipeline = [limit_stage, project_stage1, unwind_stage1, project_stage2, unwind_stage2, project_stage3, 
            match_stage1, group_stage1]

pipeline2 = [limit_stage, project_stage1, unwind_stage1, project_stage2, unwind_stage2, project_stage3, 
             match_stage1, group_stage2]


for doc in messages_collection.aggregate(pipeline):
    to_data.append(doc)

for doc in messages_collection.aggregate(pipeline2):
    from_data.append(doc)
        

for user_data in to_data:
    email = user_data['_id']
    to_emails.append(email)
    
    
for user_data in from_data:
    email = user_data['_id']
    from_emails.append(email)
    
print (from_emails)
# Out:
# ['shanna.husser@enron.com', 'matthew.lenhart@enron.com', 'luis.mena@enron.com', 'customers@travelnow.com', 'daphneco64@bigplanet.com', 'michael.simmons@enron.com', 'bryant@cheatsheets.net', 'steve.venturatos@enron.com']

# %% [markdown]
# ### 6)
#
# Write a function with parameter limit. The function should return for each email account: the number of emails sent, the number of emails received, and the total number of emails (sent and received). Use the following format: [{"contact": "michael.simmons@enron.com", "from": 42, "to": 92, "total": 134}] and the information contained in the To, From, and Cc headers. Sort the output in descending order by the total number of emails. Use the parameter limit to specify the number of results to be returned. If limit is null, the function should return all results. If limit is higher than null, the function should return the number of results specified as limit. limit cannot take negative values. [10 points]

# %%
def get_emails_between_contacts(collection, limit):
    """
    Shows the communications between contacts
    Sort by the descending order of total emails using the To, From, and Cc headers.
    :param `collection` A PyMongo collection object    
    :param `limit` An integer specifying the amount to display, or
    if null will display all outputs
    :return A list of objects of the form:
    [{
        'contact': <<Another email address>>
        'from': 
        'to': 
        'total': 
    },{.....}]
    """    
    # YOUR CODE HERE
    
    pass

# %% [markdown]
# ### 7)
# Write a function to find out the number of senders who were also direct receivers. Direct receiver means the email is sent to the person directly, not via cc or bcc. [4 points]

# %%
def get_from_to_people(collection):
    """
    :param collection A PyMongo collection object
    :return the NUMBER of the people who have sent emails and received emails as direct receivers.
    """    
    # YOUR CODE HERE

    pass

# %%
direct_receivers = []

direct_receivers1 = []

limit_stage = {
    '$limit': 100
}

project_stage1 = {
    '$project': {
        'To': '$headers.To',
        '_id': 0
    }
}


for doc in messages_collection.find({ 'headers.To': {'$exists': True, '$ne': ''} }).limit(10):
    direct_receivers.append(doc['headers']['To'])

for receivers in direct_receivers:
    for receiver in receivers.split(', '):
        if receiver.strip(' \t\n\r') not in direct_receivers1:
            direct_receivers1.append(receiver.strip(' \t\n\r'))
        
direct_receivers1
# Out:
# ['eric.bass@enron.com',
#  'cheatsheets@egroups.com',
#  'lwbthemarine@bigplanet.com',
#  'jason.bass2@compaq.com',
#  'chebert108@aol.com',
#  'jody.crook@enron.com',
#  'david.baumbach@enron.com',
#  'kelly.lombardi@enron.com',
#  'bryan.hull@enron.com',
#  'patrick.ryder@enron.com',
#  'denver.plachy@enron.com',
#  'yvette.connevey@enron.com',
#  'pat.clynes@enron.com',
#  'daren.farmer@enron.com',
#  'ebass@enron.com',
#  'chad.landry@enron.com',
#  'timothy.blanchard@enron.com',
#  'phillip.love@enron.com',
#  'kenneth.shulklapper@enron.com',
#  'jay.reitmeyer@enron.com',
#  'tori.kuykendall@enron.com',
#  'lisa.gillette@enron.com',
#  'christa.winfrey@enron.com']

# %%
direct_senders = []

direct_senders1 = []


for doc in messages_collection.find({ 'headers.From': {'$exists': True, '$ne': ''} }).limit(100):
    direct_senders.append(doc['headers']['From'])

direct_senders

print (len(direct_senders))

for sender in direct_senders:
    if sender not in direct_senders1:
        direct_senders1.append(sender)
        
        
direct_senders1

print (len(set(direct_receivers1).intersection(direct_senders1)))
# Out:
# 100
# 6

# %% [markdown]
# ### 8)
# Write a function with parameters start_date and end_date, which returns the number of email messages that have been sent between those specified dates, including start_date and end_date [4 points]

# %%
len('Tue, 14 Nov 2000 08:22:00')
# Out:
# 25

# %%
def get_emails_between_dates(collection, start_date, end_date):
    """
    :param collection A PyMongo collection object
    :return All emails between the specified start_date and end_date
    """    
    # YOUR CODE HERE 
    
    start_date_as_date = ''
    end_date_as_date = ''
    
    # start date and end date to be in form: Tue, 14 Nov 2000 08:22:00 -0800 (PST)
    # or in form: Tue, 14 Nov 2000 08:22:00
    if len(start_date) <= 25 and len(end_date) <= 25:
        # parse
        start_date_as_date = datetime.strptime(start_date, '%a, %d %b %Y %H:%M:%S')
        end_date_as_date = datetime.strptime(end_date, '%a, %d %b %Y %H:%M:%S')
    
    
    limit_stage = {
    '$limit': 100
    }



    project_stage = {
         '$project': { 'DateOfMessage': 
                          {'$dateFromString': { 'dateString' : 
                                               { '$rtrim': {'input': {'$substr': ['$headers.Date', 0, 25] }}}

                                              }
                          },

                            'filename': 1,
                            'headers.Date': 1,
                     } 
    }
    
    match_stage = {
        '$match': {
            '$and': [ {'DateOfMessage' : { '$gte': start_date_as_date } },  
                      {'DateOfMessage' : { '$lte': end_date_as_date } } ]
        }
    }
    
    
    group_stage1 = {
        '$group': {
            '_id': None, 'count': {'$sum': 1}
        }
    }
    
    project_stage2 = {
        '$project': {
            '_id': 0,
            'count_of_emails_sent': '$count',
            'start_date': start_date_as_date,
            'end_date': end_date_as_date
        }
    }
    

    pipeline = [limit_stage, project_stage, match_stage, group_stage1, project_stage2]
    
    for doc in collection.aggregate(pipeline):
        pprint(doc)
    
    
get_emails_between_dates(messages_collection, "Sat, 11 Nov 2000 16:30:00", "Mon, 13 Nov 2000 16:28:00")
# Out:
# {'count_of_emails_sent': 40,
#  'end_date': datetime.datetime(2000, 11, 13, 16, 28),
#  'start_date': datetime.datetime(2000, 11, 11, 16, 30)}

# %% [markdown]
# ## Task 2
# This task will assess your ability to use the Hadoop Streaming API and MapReduce to process data. For each of the questions below, you are expected to write two python scripts, one for the Map phase and one for the Reduce phase. You are also expected to provide the correct parameters to the `hadoop` command to run the MapReduce process. Write down your answers in the specified cells below.
#
# To get started, you need to download and unzip the YouTube dataset (available at http://edshare.soton.ac.uk/19547/) onto the machine where you have Hadoop installed (this should be the virtual machine provided).
#
# To help you, `%%writefile` has been added to the top of the cells, automatically writing them to "mapper.py" and "reducer.py" respectively when the cells are run.

# %% [markdown]
# ### 1)
# Using Youtube01-Psy.csv, find the hourly interval in which most spam was sent. The output should be in the form of a single key-value pair, where the value is a datetime at the start of the hour with the highest number of spam comments. [9 points]

# %%
# %%writefile mapper.py
#!/usr/bin/env python
#Answer for mapper.py
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/env python
#Answer for reducer.py
# Out:
# Overwriting reducer.py

# %%
# %%bash
# #Hadoop command to run the map reduce.
#
# hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-*.jar \
# -files    \
# -input    \
# -mapper   \
# -reducer  \
# -output output
# Out:
# bash: line 3: hadoop: command not found

# %%
#Expected key-value output format:
#hour_with_most_spam	"2013-11-10T10:00:00"

#Additional key-value pairs are acceptable, as long as the hour_with_most_spam pair is correct.

# %% [markdown]
# ### 2)
# Find all comments associated with a username (the AUTHOR field). Return a JSON array of all comments associated with that username. (This should use the data from all 5 data files: Psy, KatyPerry, LMFAO, Eminem, Shakira) [11 points]

# %%
# %%writefile mapper.py
#!/usr/bin/env python
#Answer for mapper.py
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/env python
#Answer for reducer.py
# Out:
# Overwriting reducer.py

# %%
# %%bash
# #Hadoop command to run the map reduce.
#
# hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-*.jar \
# -files    \
# -input    \
# -mapper   \
# -reducer  \
# -output output
# Out:
# bash: line 3: hadoop: command not found

# %%
#Expected key-value output format:
#John Smith	["Comment 1", "Comment 2", "Comment 3", "etc."]
#Jane Doe	["Comment 1", "Comment 2", "Comment 3", "etc."]
